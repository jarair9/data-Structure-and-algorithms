# %% [markdown]
# # Merge Sort, Quicksort and Divide-n-Conquer Algorithms in Python
#
# [Data Structures and Algorithms in Python](https://jovian.ai/learn/data-structures-and-algorithms-in-python) is a beginner-friendly introduction to common data structures (linked lists, stacks, queues, graphs) and algorithms (search, sorting, recursion, dynamic programming) in Python, designed to help you prepare for coding interviews and assessments.
#
# Earn a verified certificate of accomplishment for this course by signing up here: http://pythondsa.com. Ask questions, get help & participate in discussions on the [course community forum](https://jovian.ai/forum/c/data-structures-and-algorithms-in-python/78).

# %% [markdown]
# ### Prerequisites
#
# This course assumes very little background in programming and mathematics, and you can learn the required concepts here:
#
# - Basic programming with Python ([variables](https://jovian.ai/aakashns/first-steps-with-python), [data types](https://jovian.ai/aakashns/python-variables-and-data-types), [loops](https://jovian.ai/aakashns/python-branching-and-loops), [functions](https://jovian.ai/aakashns/python-functions-and-scope) etc.)
# - Some high school mathematics ([polynomials](https://www.youtube.com/watch?v=Vm7H0VTlIco), [vectors, matrices](https://www.youtube.com/watch?v=0oGJTQCy4cQ&list=PLSQl0a2vh4HCs4zPpOEdF2GuydqS90Yb6) and [probability](https://www.youtube.com/watch?v=uzkc-qNVoOk))
# - No prior knowledge of data structures or algorithms is required
#
# We'll cover any additional mathematical and theoretical concepts we need as we go along.

# %% [markdown]
# ### How to Run the Code
#
# The best way to learn the material is to execute the code and experiment with it yourself. This tutorial is an executable [Jupyter notebook](https://jupyter.org). You can _run_ this tutorial and experiment with the code examples in a couple of ways: *using free online resources* (recommended) or *on your computer*.
#
# #### Option 1: Running using free online resources (1-click, recommended)
#
# The easiest way to start executing the code is to click the **Run** button at the top of this page and select **Run on Binder**. You can also select "Run on Colab" or "Run on Kaggle", but you'll need to create an account on [Google Colab](https://colab.research.google.com) or [Kaggle](https://kaggle.com) to use these platforms.
#
#
# #### Option 2: Running on your computer locally
#
# To run the code on your computer locally, you'll need to set up [Python](https://www.python.org), download the notebook and install the required libraries. We recommend using the [Conda](https://docs.conda.io/projects/conda/en/latest/user-guide/install/) distribution of Python. Click the **Run** button at the top of this page, select the **Run Locally** option, and follow the instructions.

# %% [markdown]
# ## Problem
#
#
# In this notebook, we'll focus on solving the following problem:
#
# > **QUESTION 1**: You're working on a new feature on Jovian called "Top Notebooks of the Week". Write a function to sort a list of notebooks in decreasing order of likes. Keep in mind that up to millions of notebooks  can be created every week, so your function needs to be as efficient as possible.
#
#
# The problem of sorting a list of objects comes up over and over in computer science and software development, and it's important to understand common approaches for sorting, and the trade-offs they offer. Before we solve the above problem, we'll solve a simplified version of the problem:
#
# > **QUESTION 2**: Write a program to sort a list of numbers.
#
#
# "Sorting" usually refers to "sorting in ascending order", unless specified otherwise.

# %% [markdown]
# ## The Method
#
#
# Here's a systematic strategy we'll apply for solving problems:
#
# 1. State the problem clearly. Identify the input & output formats.
# 2. Come up with some example inputs & outputs. Try to cover all edge cases.
# 3. Come up with a correct solution for the problem. State it in plain English.
# 4. Implement the solution and test it using example inputs. Fix bugs, if any.
# 5. Analyze the algorithm's complexity and identify inefficiencies, if any.
# 6. Apply the right technique to overcome the inefficiency. Repeat steps 3 to 6.

# %% [markdown]
# ## 1. State the problem clearly. Identify the input & output formats.
#
#
# #### Problem
#
# > We need to write a function to sort a list of numbers in increasing order.
#
# #### Input
#
# 1. `nums`: A list of numbers e.g. `[4, 2, 6, 3, 4, 6, 2, 1]`
#
# #### Output
#
# 2. `sorted_nums`: The sorted version of `nums` e.g. `[1, 2, 2, 3, 4, 4, 6, 6]`
#
#
# The signature of our function would be as follows:

# %%
def sort(nums):
    pass

# %% [markdown]
# ## 2. Come up with some example inputs & outputs.
#
# Here are some scenarios we may want to test out:
#
# 1. Some lists of numbers in random order.
# 2. A list that's already sorted.
# 3. A list that's sorted in descending order.
# 4. A list containing repeating elements.
# 5. An empty list.
# 6. A list containing just one element.
# 7. A list containing one element repeated many times.
# 8. A really long list.
#
# Let's create some test cases for these scenarios. We'll represent each test case as a dictionary for easier automated testing.

# %%
# List of numbers in random order
test0 = {
    'input': {
        'nums': [4, 2, 6, 3, 4, 6, 2, 1]
    },
    'output': [1, 2, 2, 3, 4, 4, 6, 6]
}

# %%
# List of numbers in random order
test1 = {
    'input': {
        'nums': [5, 2, 6, 1, 23, 7, -12, 12, -243, 0]
    },
    'output': [-243, -12, 0, 1, 2, 5, 6, 7, 12, 23]
}

# %%
# A list that's already sorted
test2 = {
    'input': {
        'nums': [3, 5, 6, 8, 9, 10, 99]
    },
    'output': [3, 5, 6, 8, 9, 10, 99]
}

# %%
# A list that's sorted in descending order
test3 = {
    'input': {
        'nums': [99, 10, 9, 8, 6, 5, 3]
    },
    'output': [3, 5, 6, 8, 9, 10, 99]
}

# %%
# A list containing repeating elements
test4 = {
    'input': {
        'nums': [5, -12, 2, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]
    },
    'output': [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
}

# %%
# An empty list 
test5 = {
    'input': {
        'nums': []
    },
    'output': []
}

# %%
# A list containing just one element
test6 = {
    'input': {
        'nums': [23]
    },
    'output': [23]
}

# %%
# A list containing one element repeated many times
test7 = {
    'input': {
        'nums': [42, 42, 42, 42, 42, 42, 42]
    },
    'output': [42, 42, 42, 42, 42, 42, 42]
}

# %% [markdown]
# To create the final test case (a really long list), we can start with a sorted list created using `range` and shuffle it to create the input.

# %%
import random

in_list = list(range(10000))
out_list = list(range(10000))
random.shuffle(in_list)

test8 = {
    'input': {
        'nums': in_list
    },
    'output': out_list
}

# %%
tests = [test0, test1, test2, test3, test4, test5, test6, test7, test8]

# %% [markdown]
# ## 3. Come up with a correct solution. State it in plain English.
#
# It's easy to come up with a correct solution. Here's one:
#
# 1. Iterate over the list of numbers, starting from the left
# 2. Compare each number with the number that follows it
# 3. If the number is greater than the one that follows it, swap the two elements
# 4. Repeat steps 1 to 3 till the list is sorted.
#
# We need to repeat steps 1 to 3 at most `n-1` times to ensure that the array is sorted. Can you explain why? Hint: After one iteration, the largest number in the list.
#
# This method is called **bubble sort**, as it causes smaller elements to *bubble* to the top and larger to *sink* to the bottom. Here's a visual representation of the process:
#
# ![](https://upload.wikimedia.org/wikipedia/commons/c/c8/Bubble-sort-example-300px.gif)

# %% [markdown]
# ## 4. Implement the solution and test it using example inputs.
#
# The implementation is straightforward. We'll create a copy of the list inside our function, to avoid changing it while sorting.

# %%
def bubble_sort(nums):
    # Create a copy of the list, to avoid changing it
    nums = list(nums)
    # print("Input : ", nums)
    # 4. Repeat the process n-1 times
    for _ in range(len(nums) - 1):
        print()
        # 1. Iterate over the array (except last element)
        for i in range(len(nums) - 1):
            print("Iteration: ", i)
            # 2. Compare the number with  
            if nums[i] > nums[i+1]:
                
                # 3. Swap the two elements
                nums[i], nums[i+1] = nums[i+1], nums[i]
                print(nums)
                print((nums[i], nums[i+1]),(nums[i+1], nums[i]))
        print()
    # Return the sorted list
    return nums

# %% [markdown]
# Notice how we're a tuple assignment to swap two elements in a single line of code.

# %%
x, y = 2, 3
x, y = y, x
x, y
# Out:
# (3, 2)

# %% [markdown]
# Let's test it with an example.

# %%
nums0, output0 = test0['input']['nums'], test0['output']

print('Input:', nums0)
print('Expected output:', output0)
result0 = bubble_sort(nums0)
print('Actual output:', result0)
print('Match:', result0 == output0)

# %%
result0 == output0
# Out:
# True

# %% [markdown]
# We can evaluate all the cases together using the `evaluate_test_cases` helper function from the `jovian` library.

# %%
from jovian.pythondsa import evaluate_test_cases

# %%
results = evaluate_test_cases(bubble_sort, tests)
# Out:
# TEST CASE #0
# inner:  0
# swapped: 2 4
# swapped to 4 2
# inner:  1
# inner:  2
# swapped: 3 6
# swapped to 6 3
# inner:  3
# swapped: 4 6
# swapped to 6 4
# inner:  4
# inner:  5
# swapped: 2 6
# swapped to 6 2
# inner:  6
# swapped: 1 6
# swapped to 6 1
#
# inner:  0
# inner:  1
# swapped: 3 4
# swapped to 4 3
# inner:  2
# inner:  3
# inner:  4
# swapped: 2 6
# swapped to 6 2
# inner:  5
# swapped: 1 6
# swapped to 6 1
# inner:  6
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# swapped: 2 4
# swapped to 4 2
# inner:  4
# swapped: 1 4
# swapped to 4 1
# inner:  5
# inner:  6
#
# inner:  0
# inner:  1
# inner:  2
# swapped: 2 4
# swapped to 4 2
# inner:  3
# swapped: 1 4
# swapped to 4 1
# inner:  4
# inner:  5
# inner:  6
#
# inner:  0
# inner:  1
# swapped: 2 3
# swapped to 3 2
# inner:  2
# swapped: 1 3
# swapped to 3 1
# inner:  3
# inner:  4
# inner:  5
# inner:  6
#
# inner:  0
# inner:  1
# swapped: 1 2
# swapped to 2 1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
# inner:  6
#
# inner:  0
# swapped: 1 2
# swapped to 2 1
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
# inner:  6
#
#
# Input:
# {'nums': [4, 2, 6, 3, 4, 6, 2, 1]}
#
# Expected Output:
# [1, 2, 2, 3, 4, 4, 6, 6]
#
#
# Actual Output:
# [1, 2, 2, 3, 4, 4, 6, 6]
#
# Execution Time:
# 7.905 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
# inner:  0
# swapped: 2 5
# swapped to 5 2
# inner:  1
# inner:  2
# swapped: 1 6
# swapped to 6 1
# inner:  3
# inner:  4
# swapped: 7 23
# swapped to 23 7
# inner:  5
# swapped: -12 23
# swapped to 23 -12
# inner:  6
# swapped: 12 23
# swapped to 23 12
# inner:  7
# swapped: -243 23
# swapped to 23 -243
# inner:  8
# swapped: 0 23
# swapped to 23 0
#
# inner:  0
# inner:  1
# swapped: 1 5
# swapped to 5 1
# inner:  2
# inner:  3
# inner:  4
# swapped: -12 7
# swapped to 7 -12
# inner:  5
# inner:  6
# swapped: -243 12
# swapped to 12 -243
# inner:  7
# swapped: 0 12
# swapped to 12 0
# inner:  8
#
# inner:  0
# swapped: 1 2
# swapped to 2 1
# inner:  1
# inner:  2
# inner:  3
# swapped: -12 6
# swapped to 6 -12
# inner:  4
# inner:  5
# swapped: -243 7
# swapped to 7 -243
# inner:  6
# swapped: 0 7
# swapped to 7 0
# inner:  7
# inner:  8
#
# inner:  0
# inner:  1
# inner:  2
# swapped: -12 5
# swapped to 5 -12
# inner:  3
# inner:  4
# swapped: -243 6
# swapped to 6 -243
# inner:  5
# swapped: 0 6
# swapped to 6 0
# inner:  6
# inner:  7
# inner:  8
#
# inner:  0
# inner:  1
# swapped: -12 2
# swapped to 2 -12
# inner:  2
# inner:  3
# swapped: -243 5
# swapped to 5 -243
# inner:  4
# swapped: 0 5
# swapped to 5 0
# inner:  5
# inner:  6
# inner:  7
# inner:  8
#
# inner:  0
# swapped: -12 1
# swapped to 1 -12
# inner:  1
# inner:  2
# swapped: -243 2
# swapped to 2 -243
# inner:  3
# swapped: 0 2
# swapped to 2 0
# inner:  4
# inner:  5
# inner:  6
# inner:  7
# inner:  8
#
# inner:  0
# inner:  1
# swapped: -243 1
# swapped to 1 -243
# inner:  2
# swapped: 0 1
# swapped to 1 0
# inner:  3
# inner:  4
# inner:  5
# inner:  6
# inner:  7
# inner:  8
#
# inner:  0
# swapped: -243 -12
# swapped to -12 -243
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
# inner:  6
# inner:  7
# inner:  8
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
# inner:  6
# inner:  7
# inner:  8
#
#
# Input:
# {'nums': [5, 2, 6, 1, 23, 7, -12, 12, -243, 0]}
#
# Expected Output:
# [-243, -12, 0, 1, 2, 5, 6, 7, 12, 23]
#
#
# Actual Output:
# [-243, -12, 0, 1, 2, 5, 6, 7, 12, 23]
#
# Execution Time:
# 14.491 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
#
# Input:
# {'nums': [3, 5, 6, 8, 9, 10, 99]}
#
# Expected Output:
# [3, 5, 6, 8, 9, 10, 99]
#
#
# Actual Output:
# [3, 5, 6, 8, 9, 10, 99]
#
# Execution Time:
# 0.986 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
# inner:  0
# swapped: 10 99
# swapped to 99 10
# inner:  1
# swapped: 9 99
# swapped to 99 9
# inner:  2
# swapped: 8 99
# swapped to 99 8
# inner:  3
# swapped: 6 99
# swapped to 99 6
# inner:  4
# swapped: 5 99
# swapped to 99 5
# inner:  5
# swapped: 3 99
# swapped to 99 3
#
# inner:  0
# swapped: 9 10
# swapped to 10 9
# inner:  1
# swapped: 8 10
# swapped to 10 8
# inner:  2
# swapped: 6 10
# swapped to 10 6
# inner:  3
# swapped: 5 10
# swapped to 10 5
# inner:  4
# swapped: 3 10
# swapped to 10 3
# inner:  5
#
# inner:  0
# swapped: 8 9
# swapped to 9 8
# inner:  1
# swapped: 6 9
# swapped to 9 6
# inner:  2
# swapped: 5 9
# swapped to 9 5
# inner:  3
# swapped: 3 9
# swapped to 9 3
# inner:  4
# inner:  5
#
# inner:  0
# swapped: 6 8
# swapped to 8 6
# inner:  1
# swapped: 5 8
# swapped to 8 5
# inner:  2
# swapped: 3 8
# swapped to 8 3
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# swapped: 5 6
# swapped to 6 5
# inner:  1
# swapped: 3 6
# swapped to 6 3
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# swapped: 3 5
# swapped to 5 3
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
#
# Input:
# {'nums': [99, 10, 9, 8, 6, 5, 3]}
#
# Expected Output:
# [3, 5, 6, 8, 9, 10, 99]
#
#
# Actual Output:
# [3, 5, 6, 8, 9, 10, 99]
#
# Execution Time:
# 5.232 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
# inner:  0
# swapped: -12 5
# swapped to 5 -12
# inner:  1
# swapped: 2 5
# swapped to 5 2
# inner:  2
# inner:  3
# swapped: 1 6
# swapped to 6 1
# inner:  4
# inner:  5
# swapped: 7 23
# swapped to 23 7
# inner:  6
# swapped: 7 23
# swapped to 23 7
# inner:  7
# swapped: -12 23
# swapped to 23 -12
# inner:  8
# swapped: 6 23
# swapped to 23 6
# inner:  9
# swapped: 12 23
# swapped to 23 12
# inner:  10
# swapped: 1 23
# swapped to 23 1
# inner:  11
# swapped: -243 23
# swapped to 23 -243
# inner:  12
# swapped: 1 23
# swapped to 23 1
# inner:  13
# swapped: 0 23
# swapped to 23 0
#
# inner:  0
# inner:  1
# inner:  2
# swapped: 1 5
# swapped to 5 1
# inner:  3
# inner:  4
# inner:  5
# inner:  6
# swapped: -12 7
# swapped to 7 -12
# inner:  7
# swapped: 6 7
# swapped to 7 6
# inner:  8
# inner:  9
# swapped: 1 12
# swapped to 12 1
# inner:  10
# swapped: -243 12
# swapped to 12 -243
# inner:  11
# swapped: 1 12
# swapped to 12 1
# inner:  12
# swapped: 0 12
# swapped to 12 0
# inner:  13
#
# inner:  0
# inner:  1
# swapped: 1 2
# swapped to 2 1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
# swapped: -12 7
# swapped to 7 -12
# inner:  6
# swapped: 6 7
# swapped to 7 6
# inner:  7
# inner:  8
# swapped: 1 7
# swapped to 7 1
# inner:  9
# swapped: -243 7
# swapped to 7 -243
# inner:  10
# swapped: 1 7
# swapped to 7 1
# inner:  11
# swapped: 0 7
# swapped to 7 0
# inner:  12
# inner:  13
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# swapped: -12 6
# swapped to 6 -12
# inner:  5
# inner:  6
# inner:  7
# swapped: 1 7
# swapped to 7 1
# inner:  8
# swapped: -243 7
# swapped to 7 -243
# inner:  9
# swapped: 1 7
# swapped to 7 1
# inner:  10
# swapped: 0 7
# swapped to 7 0
# inner:  11
# inner:  12
# inner:  13
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# swapped: -12 5
# swapped to 5 -12
# inner:  4
# inner:  5
# inner:  6
# swapped: 1 6
# swapped to 6 1
# inner:  7
# swapped: -243 6
# swapped to 6 -243
# inner:  8
# swapped: 1 6
# swapped to 6 1
# inner:  9
# swapped: 0 6
# swapped to 6 0
# inner:  10
# inner:  11
# inner:  12
# inner:  13
#
# inner:  0
# inner:  1
# inner:  2
# swapped: -12 2
# swapped to 2 -12
# inner:  3
# inner:  4
# inner:  5
# swapped: 1 6
# swapped to 6 1
# inner:  6
# swapped: -243 6
# swapped to 6 -243
# inner:  7
# swapped: 1 6
# swapped to 6 1
# inner:  8
# swapped: 0 6
# swapped to 6 0
# inner:  9
# inner:  10
# inner:  11
# inner:  12
# inner:  13
#
# inner:  0
# inner:  1
# swapped: -12 1
# swapped to 1 -12
# inner:  2
# inner:  3
# inner:  4
# swapped: 1 5
# swapped to 5 1
# inner:  5
# swapped: -243 5
# swapped to 5 -243
# inner:  6
# swapped: 1 5
# swapped to 5 1
# inner:  7
# swapped: 0 5
# swapped to 5 0
# inner:  8
# inner:  9
# inner:  10
# inner:  11
# inner:  12
# inner:  13
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# swapped: 1 2
# swapped to 2 1
# inner:  4
# swapped: -243 2
# swapped to 2 -243
# inner:  5
# swapped: 1 2
# swapped to 2 1
# inner:  6
# swapped: 0 2
# swapped to 2 0
# inner:  7
# inner:  8
# inner:  9
# inner:  10
# inner:  11
# inner:  12
# inner:  13
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# swapped: -243 1
# swapped to 1 -243
# inner:  4
# inner:  5
# swapped: 0 1
# swapped to 1 0
# inner:  6
# inner:  7
# inner:  8
# inner:  9
# inner:  10
# inner:  11
# inner:  12
# inner:  13
#
# inner:  0
# inner:  1
# inner:  2
# swapped: -243 1
# swapped to 1 -243
# inner:  3
# inner:  4
# swapped: 0 1
# swapped to 1 0
# inner:  5
# inner:  6
# inner:  7
# inner:  8
# inner:  9
# inner:  10
# inner:  11
# inner:  12
# inner:  13
#
# inner:  0
# inner:  1
# swapped: -243 -12
# swapped to -12 -243
# inner:  2
# inner:  3
# swapped: 0 1
# swapped to 1 0
# inner:  4
# inner:  5
# inner:  6
# inner:  7
# inner:  8
# inner:  9
# inner:  10
# inner:  11
# inner:  12
# inner:  13
#
# inner:  0
# swapped: -243 -12
# swapped to -12 -243
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
# inner:  6
# inner:  7
# inner:  8
# inner:  9
# inner:  10
# inner:  11
# inner:  12
# inner:  13
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
# inner:  6
# inner:  7
# inner:  8
# inner:  9
# inner:  10
# inner:  11
# inner:  12
# inner:  13
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
# inner:  6
# inner:  7
# inner:  8
# inner:  9
# inner:  10
# inner:  11
# inner:  12
# inner:  13
#
#
# Input:
# {'nums': [5, -12, 2, 6, 1, 23, 7, 7, -12, 6, 12, 1, -243, 1, 0]}
#
# Expected Output:
# [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
#
#
# Actual Output:
# [-243, -12, -12, 0, 1, 1, 1, 2, 5, 6, 6, 7, 7, 12, 23]
#
# Execution Time:
# 21.493 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'nums': []}
#
# Expected Output:
# []
#
#
# Actual Output:
# []
#
# Execution Time:
# 0.006 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #6
#
# Input:
# {'nums': [23]}
#
# Expected Output:
# [23]
#
#
# Actual Output:
# [23]
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #7
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
# inner:  0
# inner:  1
# inner:  2
# inner:  3
# inner:  4
# inner:  5
#
#
# Input:
# {'nums': [42, 42, 42, 42, 42, 42, 42]}
#
# Expected Output:
# [42, 42, 42, 42, 42, 42, 42]
#
#
# Actual Output:
# [42, 42, 42, 42, 42, 42, 42]
#
# Execution Time:
# 0.917 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #8
# inner:  0
# inner:  1
# inner:  2
# swapped: 6821 8164
# swapped to 8164 6821
# inner:  3
# inner:  4
# swapped: 2309 8759
# swapped to 8759 2309
# inner:  5
# swapped: 1004 8759
# swapped to 8759 1004
# inner:  6
# swapped: 942 8759
# swapped to 8759 942
# inner:  7
# swapped: 6858 8759
# swapped to 8759 6858
# inner:  8
# swapped: 2192 8759
# swapped to 8759 2192
# inner:  9
# inner:  10
# swapped: 1771 8895
# swapped to 8895 1771
# inner:  11
# swapped: 6559 8895
# swapped to 8895 6559
# inner:  12
# swapped: 6944 8895
# swapped to 8895 6944
# inner:  13
# swapped: 4169 8895
# swapped to 8895 4169
# inner:  14
# swapped: 750 8895
# swapped to 8895 750
# inner:  15
# swapped: 2887 8895
# swapped to 8895 2887
# inner:  16
# inner:  17
# swapped: 3356 9318
# swapped to 9318 3356
# inner:  18
# swapped: 1633 9318
# swapped to 9318 1633
# inner:  19
# swapped: 2205 9318
# swapped to 9318 2205
# inner:  20
# swapped: 5111 9318
# swapped to 9318 5111
# inner:  21
# inner:  22
# swapped: 1367 9809
# swapped to 9809 1367
# inner:  23
# swapped: 5617 9809
# swapped to 9809 5617
# inner:  24
# swapped: 1574 9809
# swapped to 9809 1574
# inner:  25
# swapped: 5565 9809
# swapped to 9809 5565
# inner:  26
# swapped: 3606 9809
# swapped to 9809 3606
# inner:  27
# swapped: 8725 9809
# swapped to 9809 8725
# inner:  28
# swapped: 2853 9809
# swapped to 9809 2853
# inner:  29
# swapped: 160 9809
# swapped to 9809 160
# inner:  30
# swapped: 109 9809
# swapped to 9809 109
# inner:  31
# swapped: 2818 9809
# swapped to 9809 2818
# inner:  32
# swapped: 7655 9809
# swapped to 9809 7655
# inner:  33
# swapped: 2649 9809
# swapped to 9809 2649
# inner:  34
# swapped: 4855 9809
# swapped to 9809 4855
# inner:  35
# swapped: 4798 9809
# swapped to 9809 4798
# inner:  36
# swapped: 2942 9809
# swapped to 9809 2942
# inner:  37
# swapped: 5435 9809
# swapped to 9809 5435
# inner:  38
# swapped: 8987 9809
# swapped to 9809 8987
# inner:  39
# swapped: 2055 9809
# swapped to 9809 2055
# inner:  40
# swapped: 2389 9809
# swapped to 9809 2389
# inner:  41
# swapped: 3960 9809
# swapped to 9809 3960
# inner:  42
# swapped: 1029 9809
# swapped to 9809 1029
# inner:  43
# swapped: 5331 9809
# swapped to 9809 5331
# inner:  44
# swapped: 6527 9809
# swapped to 9809 6527
# inner:  45
# swapped: 4931 9809
# swapped to 9809 4931
# inner:  46
# swapped: 4367 9809
# swapped to 9809 4367
# inner:  47
# swapped: 6161 9809
# swapped to 9809 6161
# inner:  48
# inner:  49
# swapped: 841 9916
# swapped to 9916 841
# inner:  50
# swapped: 100 9916
# swapped to 9916 100
# inner:  51
# swapped: 988 9916
# swapped to 9916 988
# inner:  52
# swapped: 8086 9916
# swapped to 9916 8086
# inner:  53
# swapped: 8674 9916
# swapped to 9916 8674
# inner:  54
# swapped: 2768 9916
# swapped to 9916 2768
# inner:  55
# swapped: 5339 9916
# swapped to 9916 5339
# inner:  56
# swapped: 8174 9916
# swapped to 9916 8174
# inner:  57
# swapped: 3797 9916
# swapped to 9916 3797
# inner:  58
# swapped: 2078 9916
# swapped to 9916 2078
# inner:  59
# swapped: 2417 9916
# swapped to 9916 2417
# inner:  60
# swapped: 4207 9916
# swapped to 9916 4207
# inner:  61
# swapped: 1850 9916
# swapped to 9916 1850
# inner:  62
# swapped: 7681 9916
# swapped to 9916 7681
# inner:  63
# swapped: 4731 9916
# swapped to 9916 4731
# inner:  64
# swapped: 516 9916
# swapped to 9916 516
# inner:  65
# swapped: 4260 9916
# swapped to 9916 4260
# inner:  66
# swapped: 4023 9916
# swapped to 9916 4023
# inner:  67
# swapped: 2083 9916
# swapped to 9916 2083
# inner:  68
# swapped: 1261 9916
# swapped to 9916 1261
# inner:  69
# swapped: 2325 9916
# swapped to 9916 2325
# inner:  70
# swapped: 8085 9916
# swapped to 9916 8085
# inner:  71
# swapped: 1187 9916
# swapped to 9916 1187
# inner:  72
# swapped: 1068 9916
# swapped to 9916 1068
# inner:  73
# swapped: 9206 9916
# swapped to 9916 9206
# inner:  74
# swapped: 6679 9916
# swapped to 9916 6679
# inner:  75
# swapped: 7779 9916
# swapped to 9916 7779
# inner:  76
# swapped: 8569 9916
# swapped to 9916 8569
# inner:  77
# swapped: 1808 9916
# swapped to 9916 1808
# inner:  78
# swapped: 305 9916
# swapped to 9916 305
# inner:  79
# swapped: 2422 9916
# swapped to 9916 2422
# inner:  80
# swapped: 924 9916
# swapped to 9916 924
# inner:  81
# swapped: 7714 9916
# swapped to 9916 7714
# inner:  82
# swapped: 6776 9916
# swapped to 9916 6776
# inner:  83
# swapped: 2815 9916
# swapped to 9916 2815
# inner:  84
# swapped: 6791 9916
# swapped to 9916 6791
# inner:  85
# swapped: 9835 9916
# swapped to 9916 9835
# inner:  86
# swapped: 1043 9916
# swapped to 9916 1043
# inner:  87
# swapped: 9682 9916
# swapped to 9916 9682
# inner:  88
# swapped: 197 9916
# swapped to 9916 197
# inner:  89
# swapped: 2846 9916
# swapped to 9916 2846
# inner:  90
# swapped: 1033 9916
# swapped to 9916 1033
# inner:  91
# swapped: 2670 9916
# swapped to 9916 2670
# inner:  92
# swapped: 4768 9916
# swapped to 9916 4768
# inner:  93
# swapped: 1021 9916
# swapped to 9916 1021
# inner:  94
# swapped: 9394 9916
# swapped to 9916 9394
# inner:  95
# swapped: 2451 9916
# swapped to 9916 2451
# inner:  96
# swapped: 7158 9916
# swapped to 9916 7158
# inner:  97
# swapped: 2216 9916
# swapped to 9916 2216
# inner:  98
# swapped: 8842 9916
# swapped to 9916 8842
# inner:  99
# swapped: 9544 9916
# swapped to 9916 9544
# inner:  100
# swapped: 9077 9916
# swapped to 9916 9077
# inner:  101
# swapped: 3807 9916
# swapped to 9916 3807
# inner:  102
# swapped: 5734 9916
# swapped to 9916 5734
# inner:  103
# swapped: 8281 9916
# swapped to 9916 8281
# inner:  104
# swapped: 6400 9916
# swapped to 9916 6400
# inner:  105
# swapped: 2230 9916
# swapped to 9916 2230
# inner:  106
# swapped: 480 9916
# swapped to 9916 480
# inner:  107
# swapped: 7556 9916
# swapped to 9916 7556
# inner:  108
# swapped: 5551 9916
# swapped to 9916 5551
# inner:  109
# swapped: 2693 9916
# swapped to 9916 2693
# inner:  110
# swapped: 6702 9916
# swapped to 9916 6702
# inner:  111
# swapped: 1397 9916
# swapped to 9916 1397
# inner:  112
# swapped: 125 9916
# swapped to 9916 125
# inner:  113
# swapped: 2171 9916
# swapped to 9916 2171
# inner:  114
# swapped: 6638 9916
# swapped to 9916 6638
# inner:  115
# swapped: 5452 9916
# swapped to 9916 5452
# inner:  116
# swapped: 7594 9916
# swapped to 9916 7594
# inner:  117
# swapped: 7693 9916
# swapped to 9916 7693
# inner:  118
# swapped: 9388 9916
# swapped to 9916 9388
# inner:  119
# swapped: 3856 9916
# swapped to 9916 3856
# inner:  120
# swapped: 5682 9916
# swapped to 9916 5682
# inner:  121
# swapped: 6610 9916
# swapped to 9916 6610
# inner:  122
# swapped: 4611 9916
# swapped to 9916 4611
# inner:  123
# swapped: 2048 9916
# swapped to 9916 2048
# inner:  124
# swapped: 5631 9916
# swapped to 9916 5631
# inner:  125
# swapped: 6384 9916
# swapped to 9916 6384
# inner:  126
# swapped: 9609 9916
# swapped to 9916 9609
# inner:  127
# swapped: 4526 9916
# swapped to 9916 4526
# inner:  128
# swapped: 1346 9916
# swapped to 9916 1346
# inner:  129
# swapped: 6249 9916
# swapped to 9916 6249
# inner:  130
# swapped: 6653 9916
# swapped to 9916 6653
# inner:  131
# swapped: 7446 9916
# swapped to 9916 7446
# inner:  132
# swapped: 1202 9916
# swapped to 9916 1202
# inner:  133
# swapped: 8340 9916
# swapped to 9916 8340
# inner:  134
# swapped: 4821 9916
# swapped to 9916 4821
# inner:  135
# swapped: 7381 9916
# swapped to 9916 7381
# inner:  136
# swapped: 5568 9916
# swapped to 9916 5568
# inner:  137
# swapped: 3430 9916
# swapped to 9916 3430
# inner:  138
# swapped: 1767 9916
# swapped to 9916 1767
# inner:  139
# swapped: 8472 9916
# swapped to 9916 8472
# inner:  140
# swapped: 8604 9916
# swapped to 9916 8604
# inner:  141
# swapped: 8728 9916
# swapped to 9916 8728
# inner:  142
# swapped: 8189 9916
# swapped to 9916 8189
# inner:  143
# swapped: 85 9916
# swapped to 9916 85
# inner:  144
# swapped: 2362 9916
# swapped to 9916 2362
# inner:  145
# swapped: 5997 9916
# swapped to 9916 5997
# inner:  146
# swapped: 4801 9916
# swapped to 9916 4801
# inner:  147
# swapped: 7523 9916
# swapped to 9916 7523
# inner:  148
# swapped: 2534 9916
# swapped to 9916 2534
# inner:  149
# swapped: 2787 9916
# swapped to 9916 2787
# inner:  150
# swapped: 9415 9916
# swapped to 9916 9415
# inner:  151
# swapped: 5510 9916
# swapped to 9916 5510
# inner:  152
# swapped: 3106 9916
# swapped to 9916 3106
# inner:  153
# swapped: 5628 9916
# swapped to 9916 5628
# inner:  154
# swapped: 5122 9916
# swapped to 9916 5122
# inner:  155
# swapped: 8881 9916
# swapped to 9916 8881
# inner:  156
# swapped: 400 9916
# swapped to 9916 400
# inner:  157
# swapped: 6622 9916
# swapped to 9916 6622
# inner:  158
# swapped: 1846 9916
# swapped to 9916 1846
# inner:  159
# swapped: 4810 9916
# swapped to 9916 4810
# inner:  160
# swapped: 9624 9916
# swapped to 9916 9624
# inner:  161
# swapped: 8339 9916
# swapped to 9916 8339
# inner:  162
# swapped: 4359 9916
# swapped to 9916 4359
# inner:  163
# swapped: 250 9916
# swapped to 9916 250
# inner:  164
# swapped: 5782 9916
# swapped to 9916 5782
# inner:  165
# swapped: 1431 9916
# swapped to 9916 1431
# inner:  166
# swapped: 2761 9916
# swapped to 9916 2761
# inner:  167
# swapped: 7389 9916
# swapped to 9916 7389
# inner:  168
# swapped: 8278 9916
# swapped to 9916 8278
# inner:  169
# swapped: 882 9916
# swapped to 9916 882
# inner:  170
# swapped: 3631 9916
# swapped to 9916 3631
# inner:  171
# swapped: 6549 9916
# swapped to 9916 6549
# inner:  172
# swapped: 4279 9916
# swapped to 9916 4279
# inner:  173
# swapped: 1672 9916
# swapped to 9916 1672
# inner:  174
# swapped: 6014 9916
# swapped to 9916 6014
# inner:  175
# swapped: 1508 9916
# swapped to 9916 1508
# inner:  176
# swapped: 7637 9916
# swapped to 9916 7637
# inner:  177
# swapped: 1557 9916
# swapped to 9916 1557
# inner:  178
# swapped: 8282 9916
# swapped to 9916 8282
# inner:  179
# swapped: 411 9916
# swapped to 9916 411
# inner:  180
# swapped: 5127 9916
# swapped to 9916 5127
# inner:  181
# swapped: 3793 9916
# swapped to 9916 3793
# inner:  182
# swapped: 1074 9916
# swapped to 9916 1074
# inner:  183
# swapped: 9715 9916
# swapped to 9916 9715
# inner:  184
# swapped: 8279 9916
# swapped to 9916 8279
# inner:  185
# swapped: 7690 9916
# swapped to 9916 7690
# inner:  186
# swapped: 7585 9916
# swapped to 9916 7585
# inner:  187
# swapped: 9103 9916
# swapped to 9916 9103
# inner:  188
# swapped: 5145 9916
# swapped to 9916 5145
# inner:  189
# swapped: 8429 9916
# swapped to 9916 8429
# inner:  190
# swapped: 3463 9916
# swapped to 9916 3463
# inner:  191
# swapped: 1375 9916
# swapped to 9916 1375
# inner:  192
# swapped: 7994 9916
# swapped to 9916 7994
# inner:  193
# swapped: 6457 9916
# swapped to 9916 6457
# inner:  194
# swapped: 8261 9916
# swapped to 9916 8261
# inner:  195
# swapped: 642 9916
# swapped to 9916 642
# inner:  196
# swapped: 4671 9916
# swapped to 9916 4671
# inner:  197
# swapped: 3517 9916
# swapped to 9916 3517
# inner:  198
# swapped: 1031 9916
# swapped to 9916 1031
# inner:  199
# swapped: 7139 9916
# swapped to 9916 7139
# inner:  200
# swapped: 3925 9916
# swapped to 9916 3925
# inner:  201
# swapped: 8973 9916
# swapped to 9916 8973
# inner:  202
# swapped: 7973 9916
# swapped to 9916 7973
# inner:  203
# swapped: 6379 9916
# swapped to 9916 6379
# inner:  204
# swapped: 3039 9916
# swapped to 9916 3039
# inner:  205
# swapped: 2053 9916
# swapped to 9916 2053
# inner:  206
# swapped: 3060 9916
# swapped to 9916 3060
# inner:  207
# swapped: 6951 9916
# swapped to 9916 6951
# inner:  208
# swapped: 730 9916
# swapped to 9916 730
# inner:  209
# swapped: 832 9916
# swapped to 9916 832
# inner:  210
# swapped: 5322 9916
# swapped to 9916 5322
# inner:  211
# swapped: 2824 9916
# swapped to 9916 2824
# inner:  212
# swapped: 846 9916
# swapped to 9916 846
# inner:  213
# swapped: 4576 9916
# swapped to 9916 4576
# inner:  214
# swapped: 4804 9916
# swapped to 9916 4804
# inner:  215
# swapped: 9159 9916
# swapped to 9916 9159
# inner:  216
# swapped: 4988 9916
# swapped to 9916 4988
# inner:  217
# swapped: 3457 9916
# swapped to 9916 3457
# inner:  218
# inner:  219
# swapped: 5192 9939
# swapped to 9939 5192
# inner:  220
# swapped: 5579 9939
# swapped to 9939 5579
# inner:  221
# swapped: 5727 9939
# swapped to 9939 5727
# inner:  222
# swapped: 1425 9939
# swapped to 9939 1425
# inner:  223
# swapped: 9684 9939
# swapped to 9939 9684
# inner:  224
# swapped: 8834 9939
# swapped to 9939 8834
# inner:  225
# swapped: 2707 9939
# swapped to 9939 2707
# inner:  226
# swapped: 4426 9939
# swapped to 9939 4426
# inner:  227
# swapped: 4408 9939
# swapped to 9939 4408
# inner:  228
# swapped: 8229 9939
# swapped to 9939 8229
# inner:  229
# swapped: 695 9939
# swapped to 9939 695
# inner:  230
# swapped: 6208 9939
# swapped to 9939 6208
# inner:  231
# swapped: 2876 9939
# swapped to 9939 2876
# inner:  232
# swapped: 6609 9939
# swapped to 9939 6609
# inner:  233
# swapped: 2193 9939
# swapped to 9939 2193
# inner:  234
# swapped: 877 9939
# swapped to 9939 877
# inner:  235
# swapped: 165 9939
# swapped to 9939 165
# inner:  236
# swapped: 8058 9939
# swapped to 9939 8058
# inner:  237
# swapped: 958 9939
# swapped to 9939 958
# inner:  238
# swapped: 7721 9939
# swapped to 9939 7721
# inner:  239
# swapped: 1137 9939
# swapped to 9939 1137
# inner:  240
# swapped: 1146 9939
# swapped to 9939 1146
# inner:  241
# swapped: 4422 9939
# swapped to 9939 4422
# inner:  242
# swapped: 4506 9939
# swapped to 9939 4506
# inner:  243
# swapped: 1025 9939
# swapped to 9939 1025
# inner:  244
# swapped: 1056 9939
# swapped to 9939 1056
# inner:  245
# swapped: 6754 9939
# swapped to 9939 6754
# inner:  246
# swapped: 1759 9939
# swapped to 9939 1759
# inner:  247
# swapped: 7016 9939
# swapped to 9939 7016
# inner:  248
# swapped: 4662 9939
# swapped to 9939 4662
# inner:  249
# swapped: 6635 9939
# swapped to 9939 6635
# inner:  250
# swapped: 4333 9939
# swapped to 9939 4333
# inner:  251
# swapped: 1877 9939
# swapped to 9939 1877
# inner:  252
# swapped: 6439 9939
# swapped to 9939 6439
# inner:  253
# swapped: 8316 9939
# swapped to 9939 8316
# inner:  254
# swapped: 1679 9939
# swapped to 9939 1679
# inner:  255
# swapped: 7749 9939
# swapped to 9939 7749
# inner:  256
# swapped: 3704 9939
# swapped to 9939 3704
# inner:  257
# swapped: 276 9939
# swapped to 9939 276
# inner:  258
# swapped: 8913 9939
# swapped to 9939 8913
# inner:  259
# swapped: 3692 9939
# swapped to 9939 3692
# inner:  260
# swapped: 3969 9939
# swapped to 9939 3969
# inner:  261
# swapped: 8163 9939
# swapped to 9939 8163
# inner:  262
# swapped: 6978 9939
# swapped to 9939 6978
# inner:  263
# swapped: 4243 9939
# swapped to 9939 4243
# inner:  264
# swapped: 4120 9939
# swapped to 9939 4120
# inner:  265
# swapped: 564 9939
# swapped to 9939 564
# inner:  266
# swapped: 702 9939
# swapped to 9939 702
# inner:  267
# swapped: 605 9939
# swapped to 9939 605
# inner:  268
# swapped: 9873 9939
# swapped to 9939 9873
# inner:  269
# swapped: 4912 9939
# swapped to 9939 4912
# inner:  270
# swapped: 4309 9939
# swapped to 9939 4309
# inner:  271
# swapped: 7900 9939
# swapped to 9939 7900
# inner:  272
# swapped: 46 9939
# swapped to 9939 46
# inner:  273
# swapped: 6444 9939
# swapped to 9939 6444
# inner:  274
# swapped: 2766 9939
# swapped to 9939 2766
# inner:  275
# swapped: 7788 9939
# swapped to 9939 7788
# inner:  276
# swapped: 3377 9939
# swapped to 9939 3377
# inner:  277
# swapped: 9733 9939
# swapped to 9939 9733
# inner:  278
# swapped: 770 9939
# swapped to 9939 770
# inner:  279
# swapped: 6649 9939
# swapped to 9939 6649
# inner:  280
# swapped: 904 9939
# swapped to 9939 904
# inner:  281
# swapped: 7676 9939
# swapped to 9939 7676
# inner:  282
# swapped: 4521 9939
# swapped to 9939 4521
# inner:  283
# swapped: 9416 9939
# swapped to 9939 9416
# inner:  284
# swapped: 8896 9939
# swapped to 9939 8896
# inner:  285
# swapped: 5829 9939
# swapped to 9939 5829
# inner:  286
# swapped: 4598 9939
# swapped to 9939 4598
# inner:  287
# swapped: 9200 9939
# swapped to 9939 9200
# inner:  288
# swapped: 4467 9939
# swapped to 9939 4467
# inner:  289
# swapped: 6270 9939
# swapped to 9939 6270
# inner:  290
# swapped: 6327 9939
# swapped to 9939 6327
# inner:  291
# swapped: 836 9939
# swapped to 9939 836
# inner:  292
# swapped: 4951 9939
# swapped to 9939 4951
# inner:  293
# swapped: 2356 9939
# swapped to 9939 2356
# inner:  294
# swapped: 7349 9939
# swapped to 9939 7349
# inner:  295
# swapped: 1728 9939
# swapped to 9939 1728
# inner:  296
# swapped: 8018 9939
# swapped to 9939 8018
# inner:  297
# swapped: 6180 9939
# swapped to 9939 6180
# inner:  298
# swapped: 6095 9939
# swapped to 9939 6095
# inner:  299
# swapped: 6147 9939
# swapped to 9939 6147
# inner:  300
# swapped: 5082 9939
# swapped to 9939 5082
# inner:  301
# inner:  302
# swapped: 5413 9968
# swapped to 9968 5413
# inner:  303
# swapped: 102 9968
# swapped to 9968 102
# inner:  304
# swapped: 9317 9968
# swapped to 9968 9317
# inner:  305
# swapped: 6775 9968
# swapped to 9968 6775
# inner:  306
# swapped: 9509 9968
# swapped to 9968 9509
# inner:  307
# swapped: 7094 9968
# swapped to 9968 7094
# inner:  308
# swapped: 2442 9968
# swapped to 9968 2442
# inner:  309
# swapped: 3596 9968
# swapped to 9968 3596
# inner:  310
# swapped: 1134 9968
# swapped to 9968 1134
# inner:  311
# swapped: 4660 9968
# swapped to 9968 4660
# inner:  312
# swapped: 4216 9968
# swapped to 9968 4216
# inner:  313
# swapped: 9104 9968
# swapped to 9968 9104
# inner:  314
# swapped: 9747 9968
# swapped to 9968 9747
# inner:  315
# swapped: 3215 9968
# swapped to 9968 3215
# inner:  316
# swapped: 4110 9968
# swapped to 9968 4110
# inner:  317
# swapped: 3023 9968
# swapped to 9968 3023
# inner:  318
# swapped: 3996 9968
# swapped to 9968 3996
# inner:  319
# swapped: 2950 9968
# swapped to 9968 2950
# inner:  320
# swapped: 7941 9968
# swapped to 9968 7941
# inner:  321
# swapped: 4712 9968
# swapped to 9968 4712
# inner:  322
# swapped: 7022 9968
# swapped to 9968 7022
# inner:  323
# swapped: 4575 9968
# swapped to 9968 4575
# inner:  324
# swapped: 4021 9968
# swapped to 9968 4021
# inner:  325
# swapped: 4134 9968
# swapped to 9968 4134
# inner:  326
# swapped: 3125 9968
# swapped to 9968 3125
# inner:  327
# swapped: 5467 9968
# swapped to 9968 5467
# inner:  328
# swapped: 7188 9968
# swapped to 9968 7188
# inner:  329
# swapped: 2514 9968
# swapped to 9968 2514
# inner:  330
# swapped: 4833 9968
# swapped to 9968 4833
# inner:  331
# swapped: 4858 9968
# swapped to 9968 4858
# inner:  332
# swapped: 1889 9968
# swapped to 9968 1889
# inner:  333
# swapped: 2702 9968
# swapped to 9968 2702
# inner:  334
# swapped: 5586 9968
# swapped to 9968 5586
# inner:  335
# swapped: 8521 9968
# swapped to 9968 8521
# inner:  336
# swapped: 8297 9968
# swapped to 9968 8297
# inner:  337
# swapped: 7167 9968
# swapped to 9968 7167
# inner:  338
# swapped: 1642 9968
# swapped to 9968 1642
# inner:  339
# swapped: 4354 9968
# swapped to 9968 4354
# inner:  340
# swapped: 8204 9968
# swapped to 9968 8204
# inner:  341
# swapped: 3418 9968
# swapped to 9968 3418
# inner:  342
# swapped: 9061 9968
# swapped to 9968 9061
# inner:  343
# swapped: 8141 9968
# swapped to 9968 8141
# inner:  344
# swapped: 4012 9968
# swapped to 9968 4012
# inner:  345
# swapped: 3257 9968
# swapped to 9968 3257
# inner:  346
# swapped: 3814 9968
# swapped to 9968 3814
# inner:  347
# swapped: 4403 9968
# swapped to 9968 4403
# inner:  348
# swapped: 4316 9968
# swapped to 9968 4316
# inner:  349
# swapped: 2073 9968
# swapped to 9968 2073
# inner:  350
# swapped: 5921 9968
# swapped to 9968 5921
# inner:  351
# swapped: 620 9968
# swapped to 9968 620
# inner:  352
# swapped: 1201 9968
# swapped to 9968 1201
# inner:  353
# swapped: 6552 9968
# swapped to 9968 6552
# inner:  354
# swapped: 3535 9968
# swapped to 9968 3535
# inner:  355
# swapped: 6201 9968
# swapped to 9968 6201
# inner:  356
# swapped: 1742 9968
# swapped to 9968 1742
# inner:  357
# swapped: 5961 9968
# swapped to 9968 5961
# inner:  358
# swapped: 8648 9968
# swapped to 9968 8648
# inner:  359
# swapped: 3265 9968
# swapped to 9968 3265
# inner:  360
# swapped: 9375 9968
# swapped to 9968 9375
# inner:  361
# swapped: 254 9968
# swapped to 9968 254
# inner:  362
# swapped: 4298 9968
# swapped to 9968 4298
# inner:  363
# swapped: 701 9968
# swapped to 9968 701
# inner:  364
# swapped: 7501 9968
# swapped to 9968 7501
# inner:  365
# swapped: 2591 9968
# swapped to 9968 2591
# inner:  366
# swapped: 7083 9968
# swapped to 9968 7083
# inner:  367
# swapped: 8049 9968
# swapped to 9968 8049
# inner:  368
# swapped: 9147 9968
# swapped to 9968 9147
# inner:  369
# swapped: 9543 9968
# swapped to 9968 9543
# inner:  370
# swapped: 7715 9968
# swapped to 9968 7715
# inner:  371
# swapped: 4200 9968
# swapped to 9968 4200
# inner:  372
# swapped: 2167 9968
# swapped to 9968 2167
# inner:  373
# swapped: 1329 9968
# swapped to 9968 1329
# inner:  374
# swapped: 5182 9968
# swapped to 9968 5182
# inner:  375
# swapped: 4182 9968
# swapped to 9968 4182
# inner:  376
# swapped: 5321 9968
# swapped to 9968 5321
# inner:  377
# swapped: 7826 9968
# swapped to 9968 7826
# inner:  378
# swapped: 7621 9968
# swapped to 9968 7621
# inner:  379
# swapped: 8430 9968
# swapped to 9968 8430
# inner:  380
# swapped: 4139 9968
# swapped to 9968 4139
# inner:  381
# swapped: 3241 9968
# swapped to 9968 3241
# inner:  382
# swapped: 7147 9968
# swapped to 9968 7147
# inner:  383
# swapped: 2894 9968
# swapped to 9968 2894
# inner:  384
# swapped: 3608 9968
# swapped to 9968 3608
# inner:  385
# swapped: 9367 9968
# swapped to 9968 9367
# inner:  386
# swapped: 3014 9968
# swapped to 9968 3014
# inner:  387
# swapped: 2564 9968
# swapped to 9968 2564
# inner:  388
# swapped: 7116 9968
# swapped to 9968 7116
# inner:  389
# swapped: 5172 9968
# swapped to 9968 5172
# inner:  390
# swapped: 1038 9968
# swapped to 9968 1038
# inner:  391
# swapped: 4326 9968
# swapped to 9968 4326
# inner:  392
# swapped: 609 9968
# swapped to 9968 609
# inner:  393
# swapped: 2991 9968
# swapped to 9968 2991
# inner:  394
# swapped: 3957 9968
# swapped to 9968 3957
# inner:  395
# swapped: 8343 9968
# swapped to 9968 8343
# inner:  396
# swapped: 5124 9968
# swapped to 9968 5124
# inner:  397
# swapped: 977 9968
# swapped to 9968 977
# inner:  398
# swapped: 9632 9968
# swapped to 9968 9632
# inner:  399
# swapped: 6892 9968
# swapped to 9968 6892
# inner:  400
# swapped: 5834 9968
# swapped to 9968 5834
# inner:  401
# swapped: 3453 9968
# swapped to 9968 3453
# inner:  402
# swapped: 7375 9968
# swapped to 9968 7375
# inner:  403
# swapped: 7486 9968
# swapped to 9968 7486
# inner:  404
# swapped: 8304 9968
# swapped to 9968 8304
# inner:  405
# swapped: 167 9968
# swapped to 9968 167
# inner:  406
# swapped: 8995 9968
# swapped to 9968 8995
# inner:  407
# swapped: 4886 9968
# swapped to 9968 4886
# inner:  408
# swapped: 1944 9968
# swapped to 9968 1944
# inner:  409
# swapped: 2166 9968
# swapped to 9968 2166
# inner:  410
# swapped: 3653 9968
# swapped to 9968 3653
# inner:  411
# swapped: 6291 9968
# swapped to 9968 6291
# inner:  412
# swapped: 2102 9968
# swapped to 9968 2102
# inner:  413
# swapped: 7370 9968
# swapped to 9968 7370
# inner:  414
# swapped: 6793 9968
# swapped to 9968 6793
# inner:  415
# swapped: 5216 9968
# swapped to 9968 5216
# inner:  416
# swapped: 3163 9968
# swapped to 9968 3163
# inner:  417
# swapped: 9109 9968
# swapped to 9968 9109
# inner:  418
# swapped: 5604 9968
# swapped to 9968 5604
# inner:  419
# swapped: 8840 9968
# swapped to 9968 8840
# inner:  420
# swapped: 3670 9968
# swapped to 9968 3670
# inner:  421
# swapped: 8369 9968
# swapped to 9968 8369
# inner:  422
# swapped: 4056 9968
# swapped to 9968 4056
# inner:  423
# swapped: 3920 9968
# swapped to 9968 3920
# inner:  424
# swapped: 105 9968
# swapped to 9968 105
# inner:  425
# swapped: 4774 9968
# swapped to 9968 4774
# inner:  426
# swapped: 5412 9968
# swapped to 9968 5412
# inner:  427
# swapped: 8063 9968
# swapped to 9968 8063
# inner:  428
# swapped: 6628 9968
# swapped to 9968 6628
# inner:  429
# swapped: 9293 9968
# swapped to 9968 9293
# inner:  430
# swapped: 8165 9968
# swapped to 9968 8165
# inner:  431
# swapped: 4504 9968
# swapped to 9968 4504
# inner:  432
# swapped: 3583 9968
# swapped to 9968 3583
# inner:  433
# swapped: 8790 9968
# swapped to 9968 8790
# inner:  434
# swapped: 8354 9968
# swapped to 9968 8354
# inner:  435
# swapped: 4747 9968
# swapped to 9968 4747
# inner:  436
# swapped: 8372 9968
# swapped to 9968 8372
# inner:  437
# swapped: 1929 9968
# swapped to 9968 1929
# inner:  438
# swapped: 7128 9968
# swapped to 9968 7128
# inner:  439
# swapped: 8223 9968
# swapped to 9968 8223
# inner:  440
# swapped: 7113 9968
# swapped to 9968 7113
# inner:  441
# swapped: 4930 9968
# swapped to 9968 4930
# inner:  442
# swapped: 7701 9968
# swapped to 9968 7701
# inner:  443
# swapped: 2024 9968
# swapped to 9968 2024
# inner:  444
# swapped: 3338 9968
# swapped to 9968 3338
# inner:  445
# swapped: 536 9968
# swapped to 9968 536
# inner:  446
# swapped: 8683 9968
# swapped to 9968 8683
# inner:  447
# swapped: 7120 9968
# swapped to 9968 7120
# inner:  448
# swapped: 4971 9968
# swapped to 9968 4971
# inner:  449
# swapped: 5513 9968
# swapped to 9968 5513
# inner:  450
# swapped: 1749 9968
# swapped to 9968 1749
# inner:  451
# swapped: 4672 9968
# swapped to 9968 4672
# inner:  452
# swapped: 3843 9968
# swapped to 9968 3843
# inner:  453
# swapped: 2448 9968
# swapped to 9968 2448
# inner:  454
# swapped: 6319 9968
# swapped to 9968 6319
# inner:  455
# swapped: 4490 9968
# swapped to 9968 4490
# inner:  456
# swapped: 2721 9968
# swapped to 9968 2721
# inner:  457
# swapped: 6692 9968
# swapped to 9968 6692
# inner:  458
# swapped: 2294 9968
# swapped to 9968 2294
# inner:  459
# swapped: 7241 9968
# swapped to 9968 7241
# inner:  460
# swapped: 9351 9968
# swapped to 9968 9351
# inner:  461
# swapped: 6772 9968
# swapped to 9968 6772
# inner:  462
# swapped: 5769 9968
# swapped to 9968 5769
# inner:  463
# swapped: 1563 9968
# swapped to 9968 1563
# inner:  464
# swapped: 2094 9968
# swapped to 9968 2094
# inner:  465
# swapped: 2406 9968
# swapped to 9968 2406
# inner:  466
# swapped: 1149 9968
# swapped to 9968 1149
# inner:  467
# swapped: 1724 9968
# swapped to 9968 1724
# inner:  468
# swapped: 5009 9968
# swapped to 9968 5009
# inner:  469
# swapped: 4287 9968
# swapped to 9968 4287
# inner:  470
# swapped: 1356 9968
# swapped to 9968 1356
# inner:  471
# swapped: 4763 9968
# swapped to 9968 4763
# inner:  472
# swapped: 5879 9968
# swapped to 9968 5879
# inner:  473
# swapped: 6078 9968
# swapped to 9968 6078
# inner:  474
# swapped: 1663 9968
# swapped to 9968 1663
# inner:  475
# swapped: 959 9968
# swapped to 9968 959
# inner:  476
# swapped: 645 9968
# swapped to 9968 645
# inner:  477
# swapped: 4104 9968
# swapped to 9968 4104
# inner:  478
# swapped: 2875 9968
# swapped to 9968 2875
# inner:  479
# swapped: 5131 9968
# swapped to 9968 5131
# inner:  480
# swapped: 5080 9968
# swapped to 9968 5080
# inner:  481
# swapped: 6827 9968
# swapped to 9968 6827
# inner:  482
# swapped: 3829 9968
# swapped to 9968 3829
# inner:  483
# swapped: 7978 9968
# swapped to 9968 7978
# inner:  484
# swapped: 4591 9968
# swapped to 9968 4591
# inner:  485
# swapped: 374 9968
# swapped to 9968 374
# inner:  486
# swapped: 2148 9968
# swapped to 9968 2148
# inner:  487
# swapped: 7030 9968
# swapped to 9968 7030
# inner:  488
# swapped: 7683 9968
# swapped to 9968 7683
# inner:  489
# swapped: 5164 9968
# swapped to 9968 5164
# inner:  490
# swapped: 8064 9968
# swapped to 9968 8064
# inner:  491
# swapped: 9014 9968
# swapped to 9968 9014
# inner:  492
# swapped: 4220 9968
# swapped to 9968 4220
# inner:  493
# swapped: 8970 9968
# swapped to 9968 8970
# inner:  494
# swapped: 1971 9968
# swapped to 9968 1971
# inner:  495
# swapped: 4170 9968
# swapped to 9968 4170
# inner:  496
# swapped: 3849 9968
# swapped to 9968 3849
# inner:  497
# swapped: 9539 9968
# swapped to 9968 9539
# inner:  498
# swapped: 768 9968
# swapped to 9968 768
# inner:  499
# swapped: 7092 9968
# swapped to 9968 7092
# inner:  500
# swapped: 1260 9968
# swapped to 9968 1260
# inner:  501
# swapped: 8938 9968
# swapped to 9968 8938
# inner:  502
# swapped: 8396 9968
# swapped to 9968 8396
# inner:  503
# swapped: 8247 9968
# swapped to 9968 8247
# inner:  504
# swapped: 7797 9968
# swapped to 9968 7797
# inner:  505
# swapped: 2271 9968
# swapped to 9968 2271
# inner:  506
# swapped: 3705 9968
# swapped to 9968 3705
# inner:  507
# swapped: 9711 9968
# swapped to 9968 9711
# inner:  508
# swapped: 6831 9968
# swapped to 9968 6831
# inner:  509
# swapped: 4212 9968
# swapped to 9968 4212
# inner:  510
# swapped: 8061 9968
# swapped to 9968 8061
# inner:  511
# swapped: 3974 9968
# swapped to 9968 3974
# inner:  512
# swapped: 6142 9968
# swapped to 9968 6142
# inner:  513
# swapped: 8955 9968
# swapped to 9968 8955
# inner:  514
# swapped: 384 9968
# swapped to 9968 384
# inner:  515
# swapped: 8726 9968
# swapped to 9968 8726
# inner:  516
# swapped: 7408 9968
# swapped to 9968 7408
# inner:  517
# swapped: 6016 9968
# swapped to 9968 6016
# inner:  518
# swapped: 2149 9968
# swapped to 9968 2149
# inner:  519
# swapped: 4385 9968
# swapped to 9968 4385
# inner:  520
# swapped: 9687 9968
# swapped to 9968 9687
# inner:  521
# swapped: 6343 9968
# swapped to 9968 6343
# inner:  522
# swapped: 5246 9968
# swapped to 9968 5246
# inner:  523
# swapped: 3878 9968
# swapped to 9968 3878
# inner:  524
# swapped: 525 9968
# swapped to 9968 525
# inner:  525
# swapped: 9294 9968
# swapped to 9968 9294
# inner:  526
# swapped: 1872 9968
# swapped to 9968 1872
# inner:  527
# swapped: 4455 9968
# swapped to 9968 4455
# inner:  528
# swapped: 8668 9968
# swapped to 9968 8668
# inner:  529
# swapped: 296 9968
# swapped to 9968 296
# inner:  530
# swapped: 4393 9968
# swapped to 9968 4393
# inner:  531
# swapped: 1923 9968
# swapped to 9968 1923
# inner:  532
# swapped: 4694 9968
# swapped to 9968 4694
# inner:  533
# swapped: 1063 9968
# swapped to 9968 1063
# inner:  534
# swapped: 3570 9968
# swapped to 9968 3570
# inner:  535
# swapped: 3016 9968
# swapped to 9968 3016
# inner:  536
# swapped: 6880 9968
# swapped to 9968 6880
# inner:  537
# swapped: 54 9968
# swapped to 9968 54
# inner:  538
# swapped: 381 9968
# swapped to 9968 381
# inner:  539
# swapped: 5541 9968
# swapped to 9968 5541
# inner:  540
# swapped: 8515 9968
# swapped to 9968 8515
# inner:  541
# swapped: 3554 9968
# swapped to 9968 3554
# inner:  542
# swapped: 6685 9968
# swapped to 9968 6685
# inner:  543
# swapped: 2733 9968
# swapped to 9968 2733
# inner:  544
# swapped: 5092 9968
# swapped to 9968 5092
# inner:  545
# swapped: 1847 9968
# swapped to 9968 1847
# inner:  546
# swapped: 6648 9968
# swapped to 9968 6648
# inner:  547
# swapped: 2277 9968
# swapped to 9968 2277
# inner:  548
# swapped: 7868 9968
# swapped to 9968 7868
# inner:  549
# swapped: 5173 9968
# swapped to 9968 5173
# inner:  550
# swapped: 8615 9968
# swapped to 9968 8615
# inner:  551
# swapped: 956 9968
# swapped to 9968 956
# inner:  552
# swapped: 5025 9968
# swapped to 9968 5025
# inner:  553
# swapped: 3442 9968
# swapped to 9968 3442
# inner:  554
# swapped: 6719 9968
# swapped to 9968 6719
# inner:  555
# swapped: 7037 9968
# swapped to 9968 7037
# inner:  556
# swapped: 3294 9968
# swapped to 9968 3294
# inner:  557
# swapped: 8509 9968
# swapped to 9968 8509
# inner:  558
# swapped: 8053 9968
# swapped to 9968 8053
# inner:  559
# swapped: 3148 9968
# swapped to 9968 3148
# inner:  560
# swapped: 4663 9968
# swapped to 9968 4663
# inner:  561
# swapped: 2243 9968
# swapped to 9968 2243
# inner:  562
# swapped: 5260 9968
# swapped to 9968 5260
# inner:  563
# swapped: 3054 9968
# swapped to 9968 3054
# inner:  564
# swapped: 6464 9968
# swapped to 9968 6464
# inner:  565
# swapped: 1863 9968
# swapped to 9968 1863
# inner:  566
# swapped: 3709 9968
# swapped to 9968 3709
# inner:  567
# swapped: 706 9968
# swapped to 9968 706
# inner:  568
# swapped: 1286 9968
# swapped to 9968 1286
# inner:  569
# swapped: 5723 9968
# swapped to 9968 5723
# inner:  570
# swapped: 472 9968
# swapped to 9968 472
# inner:  571
# swapped: 4129 9968
# swapped to 9968 4129
# inner:  572
# swapped: 8458 9968
# swapped to 9968 8458
# inner:  573
# swapped: 1904 9968
# swapped to 9968 1904
# inner:  574
# swapped: 2559 9968
# swapped to 9968 2559
# inner:  575
# swapped: 4082 9968
# swapped to 9968 4082
# inner:  576
# swapped: 6819 9968
# swapped to 9968 6819
# inner:  577
# swapped: 7485 9968
# swapped to 9968 7485
# inner:  578
# swapped: 9144 9968
# swapped to 9968 9144
# inner:  579
# swapped: 5766 9968
# swapped to 9968 5766
# inner:  580
# swapped: 3476 9968
# swapped to 9968 3476
# inner:  581
# swapped: 7769 9968
# swapped to 9968 7769
# inner:  582
# swapped: 2928 9968
# swapped to 9968 2928
# inner:  583
# swapped: 5125 9968
# swapped to 9968 5125
# inner:  584
# swapped: 2016 9968
# swapped to 9968 2016
# inner:  585
# swapped: 9802 9968
# swapped to 9968 9802
# inner:  586
# swapped: 3879 9968
# swapped to 9968 3879
# inner:  587
# swapped: 7476 9968
# swapped to 9968 7476
# inner:  588
# swapped: 2776 9968
# swapped to 9968 2776
# inner:  589
# swapped: 1083 9968
# swapped to 9968 1083
# inner:  590
# swapped: 7664 9968
# swapped to 9968 7664
# inner:  591
# swapped: 5426 9968
# swapped to 9968 5426
# inner:  592
# swapped: 9114 9968
# swapped to 9968 9114
# inner:  593
# swapped: 4554 9968
# swapped to 9968 4554
# inner:  594
# swapped: 3286 9968
# swapped to 9968 3286
# inner:  595
# swapped: 3701 9968
# swapped to 9968 3701
# inner:  596
# swapped: 5746 9968
# swapped to 9968 5746
# inner:  597
# swapped: 8753 9968
# swapped to 9968 8753
# inner:  598
# swapped: 6960 9968
# swapped to 9968 6960
# inner:  599
# swapped: 7257 9968
# swapped to 9968 7257
# inner:  600
# swapped: 1216 9968
# swapped to 9968 1216
# inner:  601
# swapped: 9432 9968
# swapped to 9968 9432
# inner:  602
# swapped: 2784 9968
# swapped to 9968 2784
# inner:  603
# swapped: 3889 9968
# swapped to 9968 3889
# inner:  604
# swapped: 5735 9968
# swapped to 9968 5735
# inner:  605
# swapped: 5783 9968
# swapped to 9968 5783
# inner:  606
# swapped: 1528 9968
# swapped to 9968 1528
# inner:  607
# swapped: 3577 9968
# swapped to 9968 3577
# inner:  608
# swapped: 6083 9968
# swapped to 9968 6083
# inner:  609
# swapped: 6723 9968
# swapped to 9968 6723
# inner:  610
# swapped: 1122 9968
# swapped to 9968 1122
# inner:  611
# swapped: 9828 9968
# swapped to 9968 9828
# inner:  612
# swapped: 6671 9968
# swapped to 9968 6671
# inner:  613
# swapped: 2045 9968
# swapped to 9968 2045
# inner:  614
# swapped: 9033 9968
# swapped to 9968 9033
# inner:  615
# swapped: 2116 9968
# swapped to 9968 2116
# inner:  616
# swapped: 4377 9968
# swapped to 9968 4377
# inner:  617
# swapped: 1981 9968
# swapped to 9968 1981
# inner:  618
# swapped: 2945 9968
# swapped to 9968 2945
# inner:  619
# swapped: 6755 9968
# swapped to 9968 6755
# inner:  620
# swapped: 9324 9968
# swapped to 9968 9324
# inner:  621
# swapped: 9930 9968
# swapped to 9968 9930
# inner:  622
# swapped: 492 9968
# swapped to 9968 492
# inner:  623
# swapped: 5461 9968
# swapped to 9968 5461
# inner:  624
# swapped: 9487 9968
# swapped to 9968 9487
# inner:  625
# swapped: 9515 9968
# swapped to 9968 9515
# inner:  626
# swapped: 8114 9968
# swapped to 9968 8114
# inner:  627
# swapped: 5342 9968
# swapped to 9968 5342
# inner:  628
# swapped: 3707 9968
# swapped to 9968 3707
# inner:  629
# swapped: 5685 9968
# swapped to 9968 5685
# inner:  630
# swapped: 4497 9968
# swapped to 9968 4497
# inner:  631
# swapped: 7611 9968
# swapped to 9968 7611
# inner:  632
# swapped: 8466 9968
# swapped to 9968 8466
# inner:  633
# swapped: 2482 9968
# swapped to 9968 2482
# inner:  634
# swapped: 7920 9968
# swapped to 9968 7920
# inner:  635
# swapped: 2689 9968
# swapped to 9968 2689
# inner:  636
# swapped: 8374 9968
# swapped to 9968 8374
# inner:  637
# swapped: 8144 9968
# swapped to 9968 8144
# inner:  638
# swapped: 7024 9968
# swapped to 9968 7024
# inner:  639
# swapped: 802 9968
# swapped to 9968 802
# inner:  640
# swapped: 6070 9968
# swapped to 9968 6070
# inner:  641
# swapped: 1036 9968
# swapped to 9968 1036
# inner:  642
# swapped: 9204 9968
# swapped to 9968 9204
# inner:  643
# swapped: 5249 9968
# swapped to 9968 5249
# inner:  644
# swapped: 8284 9968
# swapped to 9968 8284
# inner:  645
# swapped: 7505 9968
# swapped to 9968 7505
# inner:  646
# swapped: 275 9968
# swapped to 9968 275
# inner:  647
# swapped: 3337 9968
# swapped to 9968 3337
# inner:  648
# swapped: 8161 9968
# swapped to 9968 8161
# inner:  649
# swapped: 3179 9968
# swapped to 9968 3179
# inner:  650
# swapped: 2802 9968
# swapped to 9968 2802
# inner:  651
# swapped: 8909 9968
# swapped to 9968 8909
# inner:  652
# swapped: 3647 9968
# swapped to 9968 3647
# inner:  653
# swapped: 3314 9968
# swapped to 9968 3314
# inner:  654
# swapped: 2323 9968
# swapped to 9968 2323
# inner:  655
# swapped: 8347 9968
# swapped to 9968 8347
# inner:  656
# swapped: 8387 9968
# swapped to 9968 8387
# inner:  657
# swapped: 8875 9968
# swapped to 9968 8875
# inner:  658
# swapped: 7210 9968
# swapped to 9968 7210
# inner:  659
# swapped: 8616 9968
# swapped to 9968 8616
# inner:  660
# swapped: 5652 9968
# swapped to 9968 5652
# inner:  661
# swapped: 5737 9968
# swapped to 9968 5737
# inner:  662
# swapped: 9884 9968
# swapped to 9968 9884
# inner:  663
# swapped: 8617 9968
# swapped to 9968 8617
# inner:  664
# swapped: 1358 9968
# swapped to 9968 1358
# inner:  665
# swapped: 7344 9968
# swapped to 9968 7344
# inner:  666
# swapped: 1179 9968
# swapped to 9968 1179
# inner:  667
# swapped: 1144 9968
# swapped to 9968 1144
# inner:  668
# swapped: 3732 9968
# swapped to 9968 3732
# inner:  669
# swapped: 9657 9968
# swapped to 9968 9657
# inner:  670
# swapped: 9203 9968
# swapped to 9968 9203
# inner:  671
# swapped: 2529 9968
# swapped to 9968 2529
# inner:  672
# swapped: 3396 9968
# swapped to 9968 3396
# inner:  673
# swapped: 8322 9968
# swapped to 9968 8322
# inner:  674
# swapped: 6426 9968
# swapped to 9968 6426
# inner:  675
# swapped: 4957 9968
# swapped to 9968 4957
# inner:  676
# swapped: 4604 9968
# swapped to 9968 4604
# inner:  677
# swapped: 9495 9968
# swapped to 9968 9495
# inner:  678
# swapped: 7557 9968
# swapped to 9968 7557
# inner:  679
# swapped: 2986 9968
# swapped to 9968 2986
# inner:  680
# swapped: 920 9968
# swapped to 9968 920
# inner:  681
# swapped: 5380 9968
# swapped to 9968 5380
# inner:  682
# swapped: 5773 9968
# swapped to 9968 5773
# inner:  683
# swapped: 9136 9968
# swapped to 9968 9136
# inner:  684
# swapped: 3096 9968
# swapped to 9968 3096
# inner:  685
# swapped: 6575 9968
# swapped to 9968 6575
# inner:  686
# swapped: 7026 9968
# swapped to 9968 7026
# inner:  687
# swapped: 8926 9968
# swapped to 9968 8926
# inner:  688
# swapped: 8334 9968
# swapped to 9968 8334
# inner:  689
# swapped: 1996 9968
# swapped to 9968 1996
# inner:  690
# swapped: 8333 9968
# swapped to 9968 8333
# inner:  691
# swapped: 8328 9968
# swapped to 9968 8328
# inner:  692
# swapped: 92 9968
# swapped to 9968 92
# inner:  693
# swapped: 2756 9968
# swapped to 9968 2756
# inner:  694
# swapped: 7021 9968
# swapped to 9968 7021
# inner:  695
# swapped: 371 9968
# swapped to 9968 371
# inner:  696
# swapped: 864 9968
# swapped to 9968 864
# inner:  697
# swapped: 6272 9968
# swapped to 9968 6272
# inner:  698
# swapped: 6785 9968
# swapped to 9968 6785
# inner:  699
# swapped: 6387 9968
# swapped to 9968 6387
# inner:  700
# swapped: 7131 9968
# swapped to 9968 7131
# inner:  701
# swapped: 9829 9968
# swapped to 9968 9829
# inner:  702
# swapped: 8552 9968
# swapped to 9968 8552
# inner:  703
# swapped: 976 9968
# swapped to 9968 976
# inner:  704
# swapped: 4850 9968
# swapped to 9968 4850
# inner:  705
# swapped: 3431 9968
# swapped to 9968 3431
# inner:  706
# swapped: 4632 9968
# swapped to 9968 4632
# inner:  707
# swapped: 3353 9968
# swapped to 9968 3353
# inner:  708
# swapped: 144 9968
# swapped to 9968 144
# inner:  709
# swapped: 4127 9968
# swapped to 9968 4127
# inner:  710
# swapped: 8446 9968
# swapped to 9968 8446
# inner:  711
# swapped: 9262 9968
# swapped to 9968 9262
# inner:  712
# swapped: 6355 9968
# swapped to 9968 6355
# inner:  713
# swapped: 8688 9968
# swapped to 9968 8688
# inner:  714
# swapped: 3301 9968
# swapped to 9968 3301
# inner:  715
# swapped: 5566 9968
# swapped to 9968 5566
# inner:  716
# swapped: 2629 9968
# swapped to 9968 2629
# inner:  717
# swapped: 7272 9968
# swapped to 9968 7272
# inner:  718
# swapped: 6315 9968
# swapped to 9968 6315
# inner:  719
# swapped: 7474 9968
# swapped to 9968 7474
# inner:  720
# swapped: 5377 9968
# swapped to 9968 5377
# inner:  721
# swapped: 8358 9968
# swapped to 9968 8358
# inner:  722
# swapped: 260 9968
# swapped to 9968 260
# inner:  723
# swapped: 9895 9968
# swapped to 9968 9895
# inner:  724
# swapped: 3997 9968
# swapped to 9968 3997
# inner:  725
# swapped: 2840 9968
# swapped to 9968 2840
# inner:  726
# swapped: 8390 9968
# swapped to 9968 8390
# inner:  727
# swapped: 4095 9968
# swapped to 9968 4095
# inner:  728
# swapped: 481 9968
# swapped to 9968 481
# inner:  729
# swapped: 1409 9968
# swapped to 9968 1409
# inner:  730
# swapped: 7290 9968
# swapped to 9968 7290
# inner:  731
# swapped: 5603 9968
# swapped to 9968 5603
# inner:  732
# swapped: 7306 9968
# swapped to 9968 7306
# inner:  733
# swapped: 314 9968
# swapped to 9968 314
# inner:  734
# swapped: 9000 9968
# swapped to 9968 9000
# inner:  735
# swapped: 5474 9968
# swapped to 9968 5474
# inner:  736
# swapped: 4982 9968
# swapped to 9968 4982
# inner:  737
# swapped: 4936 9968
# swapped to 9968 4936
# inner:  738
# swapped: 3282 9968
# swapped to 9968 3282
# inner:  739
# swapped: 5495 9968
# swapped to 9968 5495
# inner:  740
# swapped: 6980 9968
# swapped to 9968 6980
# inner:  741
# swapped: 8431 9968
# swapped to 9968 8431
# inner:  742
# swapped: 2966 9968
# swapped to 9968 2966
# inner:  743
# swapped: 533 9968
# swapped to 9968 533
# inner:  744
# swapped: 3274 9968
# swapped to 9968 3274
# inner:  745
# swapped: 9859 9968
# swapped to 9968 9859
# inner:  746
# swapped: 9322 9968
# swapped to 9968 9322
# inner:  747
# swapped: 5261 9968
# swapped to 9968 5261
# inner:  748
# swapped: 3722 9968
# swapped to 9968 3722
# inner:  749
# swapped: 484 9968
# ...
# swapped to 9995 7778
# inner:  5980
# swapped: 7944 9995
# swapped to 9995 7944
# inner:  5981
# swapped: 7266 9995
# swapped to 9995 7266
# inner:  5982
# swapped: 6358 9995
# swapped to 9995 6358
# inner:  5983
# swapped: 7633 9995
# swapped to 9995 7633
# inner:  5984
# swapped: 8056 9995
# swapped to 9995 8056
# inner:  5985
# swapped: 3799 9995
# swapped to 9995 3799
# inner:  5986
# swapped: 6493 9995
# swapped to 9995 6493
# inner:  5987
# swapped: 55 9995
# swapped to 9995 55
# inner:  5988
# swapped: 8806 9995
# swapped to 9995 8806
# inner:  5989
# swapped: 4882 9995
# swapped to 9995 4882
# inner:  5990
# swapped: 3287 9995
# swapped to 9995 3287
# inner:  5991
# swapped: 379 9995
# swapped to 9995 379
# inner:  5992
# swapped: 8830 9995
# swapped to 9995 8830
# inner:  5993
# swapped: 3051 9995
# swapped to 9995 3051
# inner:  5994
# swapped: 5703 9995
# swapped to 9995 5703
# inner:  5995
# swapped: 8021 9995
# swapped to 9995 8021
# inner:  5996
# swapped: 5046 9995
# swapped to 9995 5046
# inner:  5997
# swapped: 3065 9995
# swapped to 9995 3065
# inner:  5998
# swapped: 3515 9995
# swapped to 9995 3515
# inner:  5999
# swapped: 4853 9995
# swapped to 9995 4853
# inner:  6000
# swapped: 1351 9995
# swapped to 9995 1351
# inner:  6001
# swapped: 1490 9995
# swapped to 9995 1490
# inner:  6002
# swapped: 7435 9995
# swapped to 9995 7435
# inner:  6003
# swapped: 1714 9995
# swapped to 9995 1714
# inner:  6004
# swapped: 8675 9995
# swapped to 9995 8675
# inner:  6005
# swapped: 1170 9995
# swapped to 9995 1170
# inner:  6006
# swapped: 6063 9995
# swapped to 9995 6063
# inner:  6007
# swapped: 934 9995
# swapped to 9995 934
# inner:  6008
# swapped: 4373 9995
# swapped to 9995 4373
# inner:  6009
# swapped: 9935 9995
# swapped to 9995 9935
# inner:  6010
# swapped: 3737 9995
# swapped to 9995 3737
# inner:  6011
# swapped: 8221 9995
# swapped to 9995 8221
# inner:  6012
# swapped: 5521 9995
# swapped to 9995 5521
# inner:  6013
# swapped: 1299 9995
# swapped to 9995 1299
# inner:  6014
# swapped: 3291 9995
# swapped to 9995 3291
# inner:  6015
# swapped: 1611 9995
# swapped to 9995 1611
# inner:  6016
# swapped: 5839 9995
# swapped to 9995 5839
# inner:  6017
# swapped: 840 9995
# swapped to 9995 840
# inner:  6018
# swapped: 5269 9995
# swapped to 9995 5269
# inner:  6019
# swapped: 5276 9995
# swapped to 9995 5276
# inner:  6020
# swapped: 316 9995
# swapped to 9995 316
# inner:  6021
# swapped: 1886 9995
# swapped to 9995 1886
# inner:  6022
# swapped: 3509 9995
# swapped to 9995 3509
# inner:  6023
# swapped: 1733 9995
# swapped to 9995 1733
# inner:  6024
# swapped: 4275 9995
# swapped to 9995 4275
# inner:  6025
# swapped: 5820 9995
# swapped to 9995 5820
# inner:  6026
# swapped: 7494 9995
# swapped to 9995 7494
# inner:  6027
# swapped: 1745 9995
# swapped to 9995 1745
# inner:  6028
# swapped: 3584 9995
# swapped to 9995 3584
# inner:  6029
# swapped: 6151 9995
# swapped to 9995 6151
# inner:  6030
# swapped: 7866 9995
# swapped to 9995 7866
# inner:  6031
# swapped: 3012 9995
# swapped to 9995 3012
# inner:  6032
# swapped: 6221 9995
# swapped to 9995 6221
# inner:  6033
# swapped: 9361 9995
# swapped to 9995 9361
# inner:  6034
# swapped: 3913 9995
# swapped to 9995 3913
# inner:  6035
# swapped: 3589 9995
# swapped to 9995 3589
# inner:  6036
# swapped: 774 9995
# swapped to 9995 774
# inner:  6037
# swapped: 8181 9995
# swapped to 9995 8181
# inner:  6038
# swapped: 8984 9995
# swapped to 9995 8984
# inner:  6039
# swapped: 2777 9995
# swapped to 9995 2777
# inner:  6040
# swapped: 5423 9995
# swapped to 9995 5423
# inner:  6041
# swapped: 587 9995
# swapped to 9995 587
# inner:  6042
# swapped: 7544 9995
# swapped to 9995 7544
# inner:  6043
# swapped: 9135 9995
# swapped to 9995 9135
# inner:  6044
# swapped: 4266 9995
# swapped to 9995 4266
# inner:  6045
# swapped: 7961 9995
# swapped to 9995 7961
# inner:  6046
# swapped: 5234 9995
# swapped to 9995 5234
# inner:  6047
# swapped: 6336 9995
# swapped to 9995 6336
# inner:  6048
# swapped: 5952 9995
# swapped to 9995 5952
# inner:  6049
# swapped: 4892 9995
# swapped to 9995 4892
# inner:  6050
# swapped: 8767 9995
# swapped to 9995 8767
# inner:  6051
# swapped: 9806 9995
# swapped to 9995 9806
# inner:  6052
# swapped: 5114 9995
# swapped to 9995 5114
# inner:  6053
# swapped: 8013 9995
# swapped to 9995 8013
# inner:  6054
# swapped: 9621 9995
# swapped to 9995 9621
# inner:  6055
# swapped: 8783 9995
# swapped to 9995 8783
# inner:  6056
# swapped: 9781 9995
# swapped to 9995 9781
# inner:  6057
# swapped: 5832 9995
# swapped to 9995 5832
# inner:  6058
# swapped: 3785 9995
# swapped to 9995 3785
# inner:  6059
# swapped: 3949 9995
# swapped to 9995 3949
# inner:  6060
# swapped: 4782 9995
# swapped to 9995 4782
# inner:  6061
# swapped: 6643 9995
# swapped to 9995 6643
# inner:  6062
# swapped: 1821 9995
# swapped to 9995 1821
# inner:  6063
# swapped: 1174 9995
# swapped to 9995 1174
# inner:  6064
# swapped: 3904 9995
# swapped to 9995 3904
# inner:  6065
# swapped: 5748 9995
# swapped to 9995 5748
# inner:  6066
# swapped: 9629 9995
# swapped to 9995 9629
# inner:  6067
# swapped: 7475 9995
# swapped to 9995 7475
# inner:  6068
# swapped: 3434 9995
# swapped to 9995 3434
# inner:  6069
# swapped: 3240 9995
# swapped to 9995 3240
# inner:  6070
# swapped: 3050 9995
# swapped to 9995 3050
# inner:  6071
# swapped: 8048 9995
# swapped to 9995 8048
# inner:  6072
# swapped: 1229 9995
# swapped to 9995 1229
# inner:  6073
# swapped: 4742 9995
# swapped to 9995 4742
# inner:  6074
# swapped: 3919 9995
# swapped to 9995 3919
# inner:  6075
# swapped: 4166 9995
# swapped to 9995 4166
# inner:  6076
# swapped: 5529 9995
# swapped to 9995 5529
# inner:  6077
# swapped: 534 9995
# swapped to 9995 534
# inner:  6078
# swapped: 8553 9995
# swapped to 9995 8553
# inner:  6079
# swapped: 5556 9995
# swapped to 9995 5556
# inner:  6080
# swapped: 354 9995
# swapped to 9995 354
# inner:  6081
# swapped: 6580 9995
# swapped to 9995 6580
# inner:  6082
# swapped: 8434 9995
# swapped to 9995 8434
# inner:  6083
# swapped: 5926 9995
# swapped to 9995 5926
# inner:  6084
# swapped: 7271 9995
# swapped to 9995 7271
# inner:  6085
# swapped: 2313 9995
# swapped to 9995 2313
# inner:  6086
# swapped: 412 9995
# swapped to 9995 412
# inner:  6087
# swapped: 6086 9995
# swapped to 9995 6086
# inner:  6088
# swapped: 9840 9995
# swapped to 9995 9840
# inner:  6089
# swapped: 1653 9995
# swapped to 9995 1653
# inner:  6090
# swapped: 2145 9995
# swapped to 9995 2145
# inner:  6091
# swapped: 5757 9995
# swapped to 9995 5757
# inner:  6092
# swapped: 3008 9995
# swapped to 9995 3008
# inner:  6093
# swapped: 716 9995
# swapped to 9995 716
# inner:  6094
# swapped: 26 9995
# swapped to 9995 26
# inner:  6095
# swapped: 7497 9995
# swapped to 9995 7497
# inner:  6096
# swapped: 5158 9995
# swapped to 9995 5158
# inner:  6097
# swapped: 1567 9995
# swapped to 9995 1567
# inner:  6098
# swapped: 8935 9995
# swapped to 9995 8935
# inner:  6099
# swapped: 8606 9995
# swapped to 9995 8606
# inner:  6100
# swapped: 5911 9995
# swapped to 9995 5911
# inner:  6101
# swapped: 7888 9995
# swapped to 9995 7888
# inner:  6102
# swapped: 152 9995
# swapped to 9995 152
# inner:  6103
# swapped: 3490 9995
# swapped to 9995 3490
# inner:  6104
# swapped: 8516 9995
# swapped to 9995 8516
# inner:  6105
# swapped: 4411 9995
# swapped to 9995 4411
# inner:  6106
# swapped: 3642 9995
# swapped to 9995 3642
# inner:  6107
# swapped: 8883 9995
# swapped to 9995 8883
# inner:  6108
# swapped: 5675 9995
# swapped to 9995 5675
# inner:  6109
# swapped: 2395 9995
# swapped to 9995 2395
# inner:  6110
# swapped: 2339 9995
# swapped to 9995 2339
# inner:  6111
# swapped: 4314 9995
# swapped to 9995 4314
# inner:  6112
# swapped: 8102 9995
# swapped to 9995 8102
# inner:  6113
# swapped: 585 9995
# swapped to 9995 585
# inner:  6114
# swapped: 8157 9995
# swapped to 9995 8157
# inner:  6115
# swapped: 9677 9995
# swapped to 9995 9677
# inner:  6116
# swapped: 7830 9995
# swapped to 9995 7830
# inner:  6117
# swapped: 7767 9995
# swapped to 9995 7767
# inner:  6118
# swapped: 7323 9995
# swapped to 9995 7323
# inner:  6119
# swapped: 9864 9995
# swapped to 9995 9864
# inner:  6120
# swapped: 2823 9995
# swapped to 9995 2823
# inner:  6121
# swapped: 9395 9995
# swapped to 9995 9395
# inner:  6122
# swapped: 3190 9995
# swapped to 9995 3190
# inner:  6123
# swapped: 5583 9995
# swapped to 9995 5583
# inner:  6124
# swapped: 1 9995
# swapped to 9995 1
# inner:  6125
# swapped: 683 9995
# swapped to 9995 683
# inner:  6126
# swapped: 4828 9995
# swapped to 9995 4828
# inner:  6127
# swapped: 7104 9995
# swapped to 9995 7104
# inner:  6128
# swapped: 6855 9995
# swapped to 9995 6855
# inner:  6129
# swapped: 9708 9995
# swapped to 9995 9708
# inner:  6130
# swapped: 98 9995
# swapped to 9995 98
# inner:  6131
# swapped: 1059 9995
# swapped to 9995 1059
# inner:  6132
# swapped: 6756 9995
# swapped to 9995 6756
# inner:  6133
# swapped: 7211 9995
# swapped to 9995 7211
# inner:  6134
# swapped: 9091 9995
# swapped to 9995 9091
# inner:  6135
# swapped: 3417 9995
# swapped to 9995 3417
# inner:  6136
# swapped: 1776 9995
# swapped to 9995 1776
# inner:  6137
# swapped: 465 9995
# swapped to 9995 465
# inner:  6138
# swapped: 8986 9995
# swapped to 9995 8986
# inner:  6139
# swapped: 9421 9995
# swapped to 9995 9421
# inner:  6140
# swapped: 2926 9995
# swapped to 9995 2926
# inner:  6141
# swapped: 7537 9995
# swapped to 9995 7537
# inner:  6142
# swapped: 5296 9995
# swapped to 9995 5296
# inner:  6143
# swapped: 654 9995
# swapped to 9995 654
# inner:  6144
# swapped: 817 9995
# swapped to 9995 817
# inner:  6145
# swapped: 7295 9995
# swapped to 9995 7295
# inner:  6146
# swapped: 1012 9995
# swapped to 9995 1012
# inner:  6147
# swapped: 3358 9995
# swapped to 9995 3358
# inner:  6148
# swapped: 4241 9995
# swapped to 9995 4241
# inner:  6149
# swapped: 14 9995
# swapped to 9995 14
# inner:  6150
# swapped: 7809 9995
# swapped to 9995 7809
# inner:  6151
# swapped: 7697 9995
# swapped to 9995 7697
# inner:  6152
# swapped: 350 9995
# swapped to 9995 350
# inner:  6153
# swapped: 1645 9995
# swapped to 9995 1645
# inner:  6154
# swapped: 4159 9995
# swapped to 9995 4159
# inner:  6155
# swapped: 767 9995
# swapped to 9995 767
# inner:  6156
# swapped: 3102 9995
# swapped to 9995 3102
# inner:  6157
# swapped: 5335 9995
# swapped to 9995 5335
# inner:  6158
# swapped: 5993 9995
# swapped to 9995 5993
# inner:  6159
# swapped: 8548 9995
# swapped to 9995 8548
# inner:  6160
# swapped: 9418 9995
# swapped to 9995 9418
# inner:  6161
# swapped: 985 9995
# swapped to 9995 985
# inner:  6162
# swapped: 5784 9995
# swapped to 9995 5784
# inner:  6163
# swapped: 8402 9995
# swapped to 9995 8402
# inner:  6164
# swapped: 1418 9995
# swapped to 9995 1418
# inner:  6165
# swapped: 2608 9995
# swapped to 9995 2608
# inner:  6166
# swapped: 8319 9995
# swapped to 9995 8319
# inner:  6167
# swapped: 6473 9995
# swapped to 9995 6473
# inner:  6168
# swapped: 361 9995
# swapped to 9995 361
# inner:  6169
# swapped: 7102 9995
# swapped to 9995 7102
# inner:  6170
# swapped: 644 9995
# swapped to 9995 644
# inner:  6171
# swapped: 6619 9995
# swapped to 9995 6619
# inner:  6172
# swapped: 6874 9995
# swapped to 9995 6874
# inner:  6173
# swapped: 2895 9995
# swapped to 9995 2895
# inner:  6174
# swapped: 4438 9995
# swapped to 9995 4438
# inner:  6175
# swapped: 8822 9995
# swapped to 9995 8822
# inner:  6176
# swapped: 791 9995
# swapped to 9995 791
# inner:  6177
# swapped: 8574 9995
# swapped to 9995 8574
# inner:  6178
# swapped: 1587 9995
# swapped to 9995 1587
# inner:  6179
# swapped: 3182 9995
# swapped to 9995 3182
# inner:  6180
# swapped: 4105 9995
# swapped to 9995 4105
# inner:  6181
# swapped: 3104 9995
# swapped to 9995 3104
# inner:  6182
# swapped: 2127 9995
# swapped to 9995 2127
# inner:  6183
# swapped: 6605 9995
# swapped to 9995 6605
# inner:  6184
# swapped: 643 9995
# swapped to 9995 643
# inner:  6185
# swapped: 8 9995
# swapped to 9995 8
# inner:  6186
# swapped: 4766 9995
# swapped to 9995 4766
# inner:  6187
# swapped: 6642 9995
# swapped to 9995 6642
# inner:  6188
# swapped: 9588 9995
# swapped to 9995 9588
# inner:  6189
# swapped: 5625 9995
# swapped to 9995 5625
# inner:  6190
# swapped: 4 9995
# swapped to 9995 4
# inner:  6191
# swapped: 4919 9995
# swapped to 9995 4919
# inner:  6192
# swapped: 808 9995
# swapped to 9995 808
# inner:  6193
# swapped: 1096 9995
# swapped to 9995 1096
# inner:  6194
# swapped: 5953 9995
# swapped to 9995 5953
# inner:  6195
# swapped: 8640 9995
# swapped to 9995 8640
# inner:  6196
# swapped: 7763 9995
# swapped to 9995 7763
# inner:  6197
# swapped: 4739 9995
# swapped to 9995 4739
# inner:  6198
# swapped: 7067 9995
# swapped to 9995 7067
# inner:  6199
# swapped: 4107 9995
# swapped to 9995 4107
# inner:  6200
# swapped: 8386 9995
# swapped to 9995 8386
# inner:  6201
# swapped: 8454 9995
# swapped to 9995 8454
# inner:  6202
# swapped: 1130 9995
# swapped to 9995 1130
# inner:  6203
# swapped: 8901 9995
# swapped to 9995 8901
# inner:  6204
# swapped: 2955 9995
# swapped to 9995 2955
# inner:  6205
# swapped: 8233 9995
# swapped to 9995 8233
# inner:  6206
# swapped: 7849 9995
# swapped to 9995 7849
# inner:  6207
# swapped: 5806 9995
# swapped to 9995 5806
# inner:  6208
# swapped: 5883 9995
# swapped to 9995 5883
# inner:  6209
# swapped: 4272 9995
# swapped to 9995 4272
# inner:  6210
# swapped: 4119 9995
# swapped to 9995 4119
# inner:  6211
# swapped: 1417 9995
# swapped to 9995 1417
# inner:  6212
# swapped: 7443 9995
# swapped to 9995 7443
# inner:  6213
# swapped: 9440 9995
# swapped to 9995 9440
# inner:  6214
# swapped: 9154 9995
# swapped to 9995 9154
# inner:  6215
# swapped: 7181 9995
# swapped to 9995 7181
# inner:  6216
# swapped: 2436 9995
# swapped to 9995 2436
# inner:  6217
# swapped: 3895 9995
# swapped to 9995 3895
# inner:  6218
# swapped: 3030
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 results = evaluate_test_cases(bubble_sort, tests)
#
# File ~/Documents/data-Structure-and-algorithms/.venv/lib/python3.11/site-packages/jovian/pythondsa/__init__.py:87, in evaluate_test_cases(function, test_cases, error_only, summary_only)
#      85 if not error_only:
#      86     print("\n\033TEST CASE #{}\033".format(i))
# ---> 87 result = evaluate_test_case(function, test_case, display=False)
#      88 results.append(result)
#      89 if error_only and not result[1]:
#
# File ~/Documents/data-Structure-and-algorithms/.venv/lib/python3.11/site-packages/jovian/pythondsa/__init__.py:65, in evaluate_test_case(function, test_case, display)
#      62     _show_test_case(test_case)
#      64 start = timer()
# ---> 65 actual_output = function(**inputs)
#      66 end = timer()
#      68 runtime = math.ceil((end - start)*1e6)/1000
#
# Cell In[39], line 16, in bubble_sort(nums)
#      12             if nums[i] > nums[i+1]:
#      13
#      14                 # 3. Swap the two elements
#      15                 nums[i], nums[i+1] = nums[i+1], nums[i]
# ---> 16                 print("swapped:" , nums[i], nums[i+1])
#      17                 print("swapped to", nums[i+1], nums[i])
#      18         print()
#      19     # Return the sorted list
#
# File ~/Documents/data-Structure-and-algorithms/.venv/lib/python3.11/site-packages/ipykernel/iostream.py:775, in OutStream.write(self, string)
#     773     self.pub_thread.schedule(self._flush)
#     774 else:
# --> 775     self._schedule_flush()
#     777 return len(string)
#
# File ~/Documents/data-Structure-and-algorithms/.venv/lib/python3.11/site-packages/ipykernel/iostream.py:671, in OutStream._schedule_flush(self)
#     668 def _schedule_in_thread():
#     669     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 671 self.pub_thread.schedule(_schedule_in_thread)
#
# File ~/Documents/data-Structure-and-algorithms/.venv/lib/python3.11/site-packages/ipykernel/iostream.py:342, in IOPubThread.schedule(self, f)
#     340     self._events.append(f)
#     341     # wake event thread (message content is ignored)
# --> 342     self._event_pipe.send(b"")
#     343 else:
#     344     f()
#
# File ~/Documents/data-Structure-and-algorithms/.venv/lib/python3.11/site-packages/zmq/sugar/socket.py:698, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     691         data = zmq.Frame(
#     692             data,
#     693             track=track,
#     694             copy=copy or None,
#     695             copy_threshold=self.copy_threshold,
#     696         )
#     697     data.group = group
# --> 698 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/_zmq.py:1152, in zmq.backend.cython._zmq.Socket.send()
# -> 1152 'Could not get source, probably due dynamically evaluated source code.'
#
# File zmq/backend/cython/_zmq.py:1200, in zmq.backend.cython._zmq.Socket.send()
# -> 1200 'Could not get source, probably due dynamically evaluated source code.'
#
# File zmq/backend/cython/_zmq.py:1468, in zmq.backend.cython._zmq._send_copy()
# -> 1468 'Could not get source, probably due dynamically evaluated source code.'
#
# File zmq/backend/cython/_zmq.py:179, in zmq.backend.cython._zmq._check_rc()
# --> 179 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %% [markdown]
# Great, looks like all our test cases passed! Although the last test case (a list of 10,000 numbers) took about 12 seconds to execute.

# %% [markdown]
# ## 5. Analyze the algorithm's complexity and identify inefficiencies
#
# The core operations in bubble sort are "compare" and "swap". To analyze the time complexity, we can simply count the total number of comparisons being made, since the total number of swaps will be less than or equal to the total number of comparisons (can you see why?).
#
# ```
# for _ in range(len(nums) - 1):
#     for i in range(len(nums) - 1):
#         if nums[i] > nums[i+1]:
#             nums[i], nums[i+1] = nums[i+1], nums[i]
# ```
#
# There are two loops, each of length `n-1`, where `n` is the number of elements in `nums`. So the total number of comparisons is $(n-1)*(n-1)$ i.e. $(n-1)^2$ i.e. $n^2 - 2n + 1$.
#
# Expressing this in the Big O notation, we can conclude that the time complexity of bubble sort is $O(n^2)$ (also known as quadratic complexity).
#
# **Exercise:** Verify that the bubble sort requires $O(1)$ additional space.
#
# The space complexity of bubble sort is $O(n)$, even thought it requires only constant/zero additional space, because the space required to store the inputs is also considered while calculating space complexity.
#
# As we saw from the last test, a list of 10,000 numbers takes about 12 seconds to be sorted using bubble sort. A list of ten times the size will 100 times longer i.e. about 20 minutes to be sorted, which is quite inefficient. A list of a million elements would take close to 2 days to be sorted.
#
#
# The inefficiency in bubble sort comes from the fact that we're shifting elements by at most one position at a time.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/c/c8/Bubble-sort-example-300px.gif)

# %% [markdown]
# ### Insertion Sort
#
# Before we look at explore more efficient sorting techniques, here's another simple sorting technique called insertion sort, where we keep the initial portion of the array sorted and insert the remaining elements one by one at the right position.

# %%
def insertion_sort(nums):
    nums = list(nums)
    
    for i in range(len(nums)):
        cur = nums.pop(i)
        j = i-1
        while j >=0 and nums[j] > cur:
            j -= 1
        nums.insert(j+1, cur)
    return nums

# %%
nums0, output0 = test0['input']['nums'], test0['output']

print('Input:', nums0)
print('Expected output:', output0)
result0 = insertion_sort(nums0)
print('Actual output:', result0)
print('Match:', result0 == output0)

# %% [markdown]
# **Exercises**:
#
# 1. Read the source code of the `insertion_sort` function and describe the algorithm in plain English. Reading source code is an essential skill for software development.
# 2. Determine the time and space complexity of insertion sort. Is it any better than bubble sort? Why or why not?

# %% [markdown]
# ### Save and upload your work to Jovian
#
# Whether you're running this Jupyter notebook online or on your computer, it's essential to save your work from time to time. You can continue working on a saved notebook later or share it with friends and colleagues to let them execute your code. [Jovian](https://jovian.ai/platform-features) offers an easy way of saving and sharing your Jupyter notebooks online.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
jovian.commit()

# %% [markdown]
# ## 6. Apply the right technique to overcome the inefficiency. Repeat Steps 3 to 6.
#
#
# To performing sorting more efficiently, we'll apply a strategy called **Divide and Conquer**, which has the following general steps:
#
# 1. Divide the inputs into two roughly equal parts.
# 2. Recursively solve the problem individually for each of the two parts.
# 3. Combine the results to solve the problem for the original inputs.
# 4. Include terminating conditions for small or indivisible inputs.
#
# Here's a visual representation of the strategy:
#
# ![](https://www.educative.io/api/edpresso/shot/5327356208087040/image/6475288173084672)
#
# ### Merge Sort
#
# Following a visual representation of the divide and conquer applied for sorting numbers. This algorithm is known as merge sort:
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e6/Merge_sort_algorithm_diagram.svg/2560px-Merge_sort_algorithm_diagram.svg.png" width="480">

# %% [markdown]
# ## 7. Come up with a correct solution. State it in Plain English.
#
# Here's a step-by-step description for merge sort:
#
# 1. If the input list is empty or contains just one element, it is already sorted. Return it.
# 2. If not, divide the list of numbers into two roughly equal parts.
# 3. Sort each part recursively using the merge sort algorithm. You'll get back two sorted lists.
# 4. Merge the two sorted lists to get a single sorted list
#
# Can you guess how the "merge" operation step 4 works? Hint: Watch this animation: https://youtu.be/GW0USDwhBgo?t=28
#
# > **QUESTION 3**: Write a function to merge two sorted arrays.
#
#
# Try to explain how the merge operation works in your own words below:
#
# 1. ???
# 2. ???
# 3. ???
# 4. ???

# %% [markdown]
# ## 8. Implement the solution and test it using example inputs
#
# Let's implement the merge sort algorithm assuming we already have a helper function called `merge` for merging two sorted arrays.

# %%
def merge_sort(nums):
    # Terminating condition (list of 0 or 1 elements)
    if len(nums) <= 1:
        return nums
    
    # Get the midpoint
    mid = len(nums) // 2
    
    # Split the list into two halves
    left = nums[:mid]
    right = nums[mid:]
    
    # Solve the problem for each half recursively
    left_sorted, right_sorted = merge_sort(left), merge_sort(right)
    
    # Combine the results of the two halves
    sorted_nums =  merge(left_sorted, right_sorted)
    
    return sorted_nums

# %% [markdown]
# Two merge two sorted arrays, we can repeatedly compare the two least elements of each array, and copy over the smaller one into a new array.
#
# Here's a visual representation of the merge operation:
#
# <img src="https://i.imgur.com/XeEpa0U.png" width="480">

# %%
def merge(nums1, nums2):    
    # List to store the results 
    merged = []
    
    # Indices for iteration
    i, j = 0, 0
    
    # Loop over the two lists
    while i < len(nums1) and j < len(nums2):        
        
        # Include the smaller element in the result and move to next element
        if nums1[i] <= nums2[j]:
            merged.append(nums1[i])
            i += 1 
        else:
            merged.append(nums2[j])
            j += 1
    
    # Get the remaining parts
    nums1_tail = nums1[i:]
    nums2_tail = nums2[j:]
    
    # Return the final merged array
    return merged + nums1_tail + nums2_tail

# %% [markdown]
# Let's test the merge operation, before we test merge sort.

# %%
merge([1, 4, 7, 9, 11], [-1, 0, 2, 3, 8, 12])

# %% [markdown]
# It seems to work as expected. We can now test the `merge_sort` function.

# %%
nums0, output0 = test0['input']['nums'], test0['output']

print('Input:', nums0)
print('Expected output:', output0)
result0 = merge_sort(nums0)
print('Actual output:', result0)
print('Match:', result0 == output0)

# %% [markdown]
# Let's test all the cases using the `evaluate_test_cases` function from `jovian`.

# %%
results = evaluate_test_cases(merge_sort, tests)

# %% [markdown]
# All the test cases have passed! Our function works as expected.
#
# Notice the last test case, the merge sort function took just 50 milliseconds to sort 10,000 numbers, which took bubble sort about 12 seconds.

# %%
jovian.commit()

# %% [markdown]
# ## 9. Analyze the algorithm's complexity and identify inefficiencies
#
# Analyzing the complexity of recursive algorithms can be tricky. It helps to track and follow the chain of recursive calls. We'll add some print statements to our `merge_sort` and `merge_functions` to display the _tree_ of recursive function calls.

# %%
def merge(nums1, nums2, depth=0):
    print('  '*depth, 'merge:', nums1, nums2)
    i, j, merged = 0, 0, []
    while i < len(nums1) and j < len(nums2):
        if nums1[i] <= nums2[j]:
            merged.append(nums1[i])
            i += 1
        else:
            merged.append(nums2[j])
            j += 1
    return merged + nums1[i:] + nums2[j:]
        
def merge_sort(nums, depth=0):
    print('  '*depth, 'merge_sort:', nums)
    if len(nums) < 2: 
        return nums
    mid = len(nums) // 2
    return merge(merge_sort(nums[:mid], depth+1), 
                 merge_sort(nums[mid:], depth+1), 
                 depth+1)

# %%
merge_sort([5, -12, 2, 6, 1, 23, 7, 7, -12])

# %% [markdown]
# We can now see that each `merge_sort` call itself invokes `merge_sort` twice (but with an array half the size), and also invokes the `merge` function once to merge the two resulting arrays. The two calls to `merge_sort` themselves make two recursive calls followed by an invocation of `merge`. The division continues till we reach an list of size 1 or 0. Thus, the merge sort algorithm ultimately boils down to a series of `merge` operations performed on arrays of varying sizes. Inside the `merge` function we perform comparisons and add numbers to a new array.
#
# **Exercise:** Verify that time complexity of the merge operation is $O(n)$, where $n$ is the sum of the sizes of the two input lists. Hint: Count the number of comparisons.
#
# To find the overall complexity of `merge_sort`, we simply need to count how many times the `merge` function was invoked and the size of the input list for each invocation. Here's how all the subproblems can be visualized:
#
#
# ![](https://i.imgur.com/j1IuS2t.png)
#
# Counting from the top and starting from 0, the $k^{th}$ level of the above tree involves $2^k$ invocations of `merge` with sublists of size roughly $n / 2^k$, where $n$ is the size of the original input list. Therefore the total number of comparisons at each level of the tree is $2^k * n/2^k = n$.
#
# Thus, if the height of the tree is $h$, the total number of comparisons is $n*h$. Since there are $n$ sublists of size 1 at the lowest level, it follows that $2^{(h-1)} = n$ i.e. $h = \log n + 1$. Thus the time complexity of the merge sort algorithms is $O(n \log n)$.
#
# As we already saw, it took just 50 ms to sort an array of 10,000 elements. Even an array of 1 million elements will take only a few seconds to be sorted.
#
#
# ### Space Complexity
#
#
#
#
# To find the space complexity of merge sort, it helps to recall that a new list with equal to the sum of the sizes of the two lists is created in each invocation of `merge`.
#
# ```
# i, j, merged = 0, 0, []
# while i < len(nums1) and j < len(nums2):
#     if nums1[i] <= nums2[j]:
#         merged.append(nums1[i])
#         i += 1
#     else:
#         merged.append(nums2[j])
#         j += 1
# ```
#
#
# At first glance, it may seem that $O(n)$ space is required for each level of the tree, so the space complexity of merge sort is $O(n \log n)$.
#
# ![](https://i.imgur.com/KTbibGC.png)
#
# However, since the original sublists can be discarded after the `merge` operation, the additional space can be freed or reused for future merge calls. Thus, merge sort requires $O(n)$ additional space i.e. the space complexity is $O(n)$.
#
#
# There are several extensions and variations and extensions of merge sort:
#
# * K-way merge sort: https://en.wikipedia.org/wiki/K-way_merge_algorithm
# * Counting inversions in an array: https://www.geeksforgeeks.org/counting-inversions/
# * Merge sort and insertion sort hybrids: https://en.wikipedia.org/wiki/Timsort

# %%
jovian.commit()

# %% [markdown]
# ## 10. Apply the right technique to overcome the inefficiency. Repeat Steps 3 to 6.
#
# The fact that merge sort requires allocating additional space as large as the input itself makes it somewhat slow in practice because memory allocation is far more expensive than comparisons or swapping.
#
# ### Quicksort
#
# To overcome the space inefficiencies of merge sort, we'll study another divide-and-conquer based sorting algorithm called **quicksort**, which works as follows:
#
# 1. If the list is empty or has just one element, return it. It's already sorted.
# 2. Pick a random element from the list. This element is called a _pivot_.
# 3. Reorder the list so that all elements with values less than or equal to the pivot come before the pivot, while all elements with values greater than the pivot come after it. This operation is called _partitioning_.
# 4. The pivot element divides the array into two parts which can be sorted independently by making a recursive call to quicksort.
#
# ![](https://images.deepai.org/glossary-terms/a5228ea07c794b468efd1b7f758b9ead/Quicksort.png)
#
# The key observation here is that after the partition, the pivot element is at its right place in the sorted array, and the two parts of the array can be sorted independently in-place.
#
# Here's an implementation of quicksort, assuming we already have a helper function called `partitions` which picks a pivot, partitions the array in-place, and returns the position of the pivot element.

# %%
def quicksort(nums, start=0, end=None):
    # print('quicksort', nums, start, end)
    if end is None:
        nums = list(nums)
        end = len(nums) - 1
    
    if start < end:
        pivot = partition(nums, start, end)
        quicksort(nums, start, pivot-1)
        quicksort(nums, pivot+1, end)

    return nums

# %% [markdown]
# Here's how the partition operation works([source](https://medium.com/basecs/pivoting-to-understand-quicksort-part-1-75178dfb9313)):
#
# <img src="https://i.imgur.com/Igk7Kr4.png" width="420">
#
#
# Here's an implementation of partition, which uses the last element of the list as a pivot:

# %%
def partition(nums, start=0, end=None):
    # print('partition', nums, start, end)
    if end is None:
        end = len(nums) - 1
    
    # Initialize right and left pointers
    l, r = start, end-1
    
    # Iterate while they're apart
    while r > l:
        # print('  ', nums, l, r)
        # Increment left pointer if number is less or equal to pivot
        if nums[l] <= nums[end]:
            l += 1
        
        # Decrement right pointer if number is greater than pivot
        elif nums[r] > nums[end]:
            r -= 1
        
        # Two out-of-place elements found, swap them
        else:
            nums[l], nums[r] = nums[r], nums[l]
    # print('  ', nums, l, r)
    # Place the pivot between the two parts
    if nums[l] > nums[end]:
        nums[l], nums[end] = nums[end], nums[l]
        return l
    else:
        return end

# %% [markdown]
# Let's see the partition function in action:

# %%
l1 = [1, 5, 6, 2, 0, 11, 3]
pivot = partition(l1)
print(l1, pivot)

# %% [markdown]
# As expected the list was partitioned using `3` as the pivot element, which finally ends up at the index `2` within the partitioned list.
#
# **Exercise:** Add print statements inside the partition function to display the list, the left pointer and the right pointer at the beginning and end of every loop, to study how the partitioning works.

# %% [markdown]
# We can now see quicksort in action:

# %%
nums0, output0 = test0['input']['nums'], test0['output']

print('Input:', nums0)
print('Expected output:', output0)
result0 = quicksort(nums0)
print('Actual output:', result0)
print('Match:', result0 == output0)

# %% [markdown]
# Let's test all the cases using the `evaluate_test_cases` function from `jovian`.

# %%
from jovian.pythondsa import evaluate_test_cases

results = evaluate_test_cases(quicksort, tests)

# %% [markdown]
# All the test cases have passed successfully! You will also notice that is also marginally faster than merge sort for larger lists.

# %% [markdown]
# ### Time Complexity of Quicksort
#
# If we assume that
#
#
# Best case partitioning:
#
# <img src="https://i.imgur.com/DgvYvnG.png" width="480">
#
#
# If we partition the list into two nearly equal parts, then the complexity analysis is similar to that of merge sort and quicksort has the complexity $O(n \log n)$. This is called the average-case complexity.
#
#
# Worst case partitioning:
#
#
# <img src="https://cdn.kastatic.org/ka-perseus-images/7da2ac32779bef669a6f05decb62f219a9132158.png" width="480">
#
# In this case, the partition is called `n` times with lists of sizes `n`, `n-1`... so that total comparisions are $n + (n-1) + (n-2) + ... + 2 + 1 = n * (n-1) / 2$. So the worst-case complexity of quicksort is $O(n^2)$.
#
# **Exercise:** Verify that quicksort requires $O(1)$ additional space.
#
# Despite the quadratic worst case time complexity Quicksort is preferred in many situations because its running time is closer to $O(n \log n)$ in practice, especially with a good strategy for picking a pivot. Some these are:
#
# - [Picking a random pivot](https://cs.stackexchange.com/questions/7582/what-is-the-advantage-of-randomized-quicksort)
# - [Picking median of medians](https://en.wikipedia.org/wiki/Median_of_medians)
#
#
# Here are some other problems you can solve using the partitioning strategy of Quicksort: https://www.techiedelight.com/problems-solved-using-partitioning-logic-quicksort/

# %%
jovian.commit()

# %% [markdown]
# ## Custom Comparison Functions
#
# Let's return to our original problem statement now.
#
# > **QUESTION 1**: You're working on a new feature on Jovian called "Top Notebooks of the Week". Write a function to sort a list of notebooks in decreasing order of likes. Keep in mind that up to millions of notebooks  can be created every week, so your function needs to be as efficient as possible.
#
# First, we need to sort objects, not just numbers. Also, we want to sort them in the descending order of likes. To achieve this, all we need is a custom comparison function to compare two notebooks.
#
# Let's create a class that captures basic information about notebooks.

# %%
class Notebook:
    def __init__(self, title, username, likes):
        self.title, self.username, self.likes = title, username, likes
        
    def __repr__(self):
        return 'Notebook <"{}/{}", {} likes>'.format(self.username, self.title, self.likes)

# %% [markdown]
# Let's create some sample notebooks

# %%
nb0 = Notebook('pytorch-basics', 'aakashns', 373)
nb1 = Notebook('linear-regression', 'siddhant', 532)
nb2 = Notebook('logistic-regression', 'vikas', 31)
nb3 = Notebook('feedforward-nn', 'sonaksh', 94)
nb4 = Notebook('cifar10-cnn', 'biraj', 2)
nb5 = Notebook('cifar10-resnet', 'tanya', 29)
nb6 = Notebook('anime-gans', 'hemanth', 80)
nb7 = Notebook('python-fundamentals', 'vishal', 136)
nb8 = Notebook('python-functions', 'aakashns', 74)
nb9 = Notebook('python-numpy', 'siddhant', 92)

# %%
notebooks = [nb0, nb1, nb2, nb3, nb4, nb5,nb6, nb7, nb8, nb9]

# %%
notebooks

# %% [markdown]
# Next, we'll define a custom comparison function for comparing two notebooks. It will return the strings `'lesser'`, `'equal'` or `'greater'` to establish order between the two objects.

# %%
def compare_likes(nb1, nb2):
    if nb1.likes > nb2.likes:
        return 'lesser'
    elif nb1.likes == nb2.likes:
        return 'equal'
    elif nb1.likes < nb2.likes:
        return 'greater'

# %% [markdown]
# Note that we say `nb1` is _lesser_ than `nb2` if it has higher likes, because we want to sort the notebooks in decreasing order of likes.
#
# Here's an implementation of merge sort which accepts a custom comparison function.

# %%
def default_compare(x, y):
    if x < y:
        return 'less'
    elif x == y:
        return 'equal'
    else:
        return 'greater'

def merge_sort(objs, compare=default_compare):
    if len(objs) < 2:
        return objs
    mid = len(objs) // 2
    return merge(merge_sort(objs[:mid], compare), 
                 merge_sort(objs[mid:], compare), 
                 compare)

def merge(left, right, compare):
    i, j, merged = 0, 0, []
    while i < len(left) and j < len(right):
        result = compare(left[i], right[j])
        if result == 'lesser' or result == 'equal':
            merged.append(left[i])
            i += 1
        else:
            merged.append(right[j])
            j += 1
    return merged + left[i:] + right[j:]

# %%
sorted_notebooks = merge_sort(notebooks, compare_likes)

# %%
sorted_notebooks

# %% [markdown]
# As you can see, the notebooks are now sorted by likes. Since we have written a generic `merge_sort` function that works with any compare function, we can also use it to sort the notebooks by title.

# %%
def compare_titles(nb1, nb2):
    if nb1.title < nb2.title:
        return 'lesser'
    elif nb1.title == nb2.title:
        return 'equal'
    elif nb1.title > nb2.title:
        return 'greater'

# %%
merge_sort(notebooks, compare_titles)

# %% [markdown]
# **Exercise:** Implement and test generic versions of bubble sort, insertion sort and quicksort using the empty cells below.

# %% [markdown]
# Let's save our work before continuing.

# %%
jovian.commit()

# %% [markdown]
# ## Summary and Exercises
#
# We've covered the following sorting algorithms in this tutorial:
#
# 1. Bubble sort
# 2. Insertion sort
# 3. Merge sort
# 4. Quick sort
#
# There are several other sorting algorithms, and most languages provide library functions for sorting that use a hybrid approach depending on the size and type of element in the list/array.
#
#
# Try out some problems on sorting and divide-n-conquer here:
#
# * https://leetcode.com/tag/sort/
# * https://www.techiedelight.com/sorting-interview-questions/
# * [HackerRank](https://www.hackerrank.com/domains/algorithms?filters%5Bsubdomains%5D%5B%5D=arrays-and-sorting)
# * https://leetcode.com/tag/divide-and-conquer/
# * https://www.geeksforgeeks.org/divide-and-conquer/
#
# Use this problem solving template: https://jovian.ai/aakashns/python-problem-solving-template
